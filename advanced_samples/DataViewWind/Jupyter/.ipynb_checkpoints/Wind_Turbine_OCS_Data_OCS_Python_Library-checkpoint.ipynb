# %%
get_ipython().magic(u'config IPCompleter.greedy=True')

# %%
import requests
import configparser
import json
import pandas as pd
from datetime import date, timedelta
from ocs_sample_library_preview import *

# %%
config = configparser.ConfigParser()
config.read('config.ini')

ocsClient = OCSClient(config.get('Access', 'ApiVersion'), config.get('Access', 'Tenant'), config.get('Access', 'Resource'), 
                        config.get('Credentials', 'ClientId'), config.get('Credentials', 'ClientSecret'))

namespaceId = config.get('Configurations', 'Namespace')
namespaceId
# Out:
# 'Derek'

# %%
#dateFrom = '2020-01-12'
#dateTo ='2020-01-23'
dateFrom = 'Mar 11, 2020, 12:00:00 AM' #str(date.today()-timedelta(days=10))
dateTo = 'Mar 12, 2020, 12:00:00 AM'# str(date.today()) #10 days of data
timeinterval = '00:01:00' #interpolate every minute

#dataviewId = Wind Turbine Data_NN, where NN is your specific student number (e.g. NN=01 in this example)
dataviewId= "Wind Turbine Data"

data, n, f = ocsClient.DataViews.getDataInterpolated(namespaceId, dataviewId, startIndex=dateFrom, endIndex=dateTo, 
                                                         interval=timeinterval, count=150000)
data
# Out:
# [{'Timestamp': '2020-03-11T00:00:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.543748,
#   'Blade2 Actual': -0.5085606,
#   'Blade3 Actual': -0.11147802,
#   'Rotor Speed': 15.482932,
#   'State': 16,
#   'Active Power': 393.81445,
#   'Nacelle Position': 304.809,
#   'Air Temperature': 57.54779,
#   'Wind Speed': 6.9476624},
#  {'Timestamp': '2020-03-11T00:01:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.54135567,
#   'Blade2 Actual': -0.5062879,
#   'Blade3 Actual': -0.0988387,
#   'Rotor Speed': 14.812955,
#   'State': 16,
#   'Active Power': 405.43518,
#   'Nacelle Position': 304.6422,
#   'Air Temperature': 57.531895,
#   'Wind Speed': 6.6366854},
#  {'Timestamp': '2020-03-11T00:02:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5389633,
#   'Blade2 Actual': -0.50401515,
#   'Blade3 Actual': -0.08619938,
#   'Rotor Speed': 13.750278,
#   'State': 16,
#   'Active Power': 307.92307,
#   'Nacelle Position': 304.4754,
#   'Air Temperature': 57.516,
#   'Wind Speed': 6.979335},
#  {'Timestamp': '2020-03-11T00:03:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.53657097,
#   'Blade2 Actual': -0.5017424,
#   'Blade3 Actual': -0.07356007,
#   'Rotor Speed': 17.696032,
#   'State': 16,
#   'Active Power': 618.7,
#   'Nacelle Position': 304.3086,
#   'Air Temperature': 57.500107,
#   'Wind Speed': 7.525977},
#  {'Timestamp': '2020-03-11T00:04:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5341786,
#   'Blade2 Actual': -0.4994697,
#   'Blade3 Actual': -0.060920745,
#   'Rotor Speed': 17.967062,
#   'State': 16,
#   'Active Power': 641,
#   'Nacelle Position': 304.21494,
#   'Air Temperature': 57.48421,
#   'Wind Speed': 8.931692},
#  {'Timestamp': '2020-03-11T00:05:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.53178626,
#   'Blade2 Actual': -0.49719697,
#   'Blade3 Actual': -0.048281424,
#   'Rotor Speed': 14.665382,
#   'State': 16,
#   'Active Power': 369.75,
#   'Nacelle Position': 304.292,
#   'Air Temperature': 57.468315,
#   'Wind Speed': 7.2064657},
#  {'Timestamp': '2020-03-11T00:06:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5293939,
#   'Blade2 Actual': -0.49492425,
#   'Blade3 Actual': -0.035642102,
#   'Rotor Speed': 16.251783,
#   'State': 16,
#   'Active Power': 478.8,
#   'Nacelle Position': 304.36905,
#   'Air Temperature': 57.45242,
#   'Wind Speed': 6.801806},
#  {'Timestamp': '2020-03-11T00:07:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.52700156,
#   'Blade2 Actual': -0.49265152,
#   'Blade3 Actual': -0.023002783,
#   'Rotor Speed': 17.437292,
#   'State': 16,
#   'Active Power': 657.55,
#   'Nacelle Position': 304.44608,
#   'Air Temperature': 57.436523,
#   'Wind Speed': 8.190707},
#  {'Timestamp': '2020-03-11T00:08:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.52460927,
#   'Blade2 Actual': -0.4903788,
#   'Blade3 Actual': -0.010363462,
#   'Rotor Speed': 19.132862,
#   'State': 16,
#   'Active Power': 871.6667,
#   'Nacelle Position': 304.52313,
#   'Air Temperature': 57.420628,
#   'Wind Speed': 9.397439},
#  {'Timestamp': '2020-03-11T00:09:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5222169,
#   'Blade2 Actual': -0.48810607,
#   'Blade3 Actual': 0.0022758574,
#   'Rotor Speed': 17.187315,
#   'State': 16,
#   'Active Power': 563.4923,
#   'Nacelle Position': 304.6002,
#   'Air Temperature': 57.40473,
#   'Wind Speed': 7.469274},
#  {'Timestamp': '2020-03-11T00:10:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.51982456,
#   'Blade2 Actual': -0.48583335,
#   'Blade3 Actual': 0.014915178,
#   'Rotor Speed': 17.507158,
#   'State': 16,
#   'Active Power': 616.4167,
#   'Nacelle Position': 304.67725,
#   'Air Temperature': 57.388836,
#   'Wind Speed': 8.385828},
#  {'Timestamp': '2020-03-11T00:11:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5174322,
#   'Blade2 Actual': -0.48356062,
#   'Blade3 Actual': 0.027554497,
#   'Rotor Speed': 15.039915,
#   'State': 16,
#   'Active Power': 358.69983,
#   'Nacelle Position': 304.75427,
#   'Air Temperature': 57.37294,
#   'Wind Speed': 7.107357},
#  {'Timestamp': '2020-03-11T00:12:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.51503986,
#   'Blade2 Actual': -0.4812879,
#   'Blade3 Actual': 0.04019382,
#   'Rotor Speed': 15.584111,
#   'State': 16,
#   'Active Power': 420,
#   'Nacelle Position': 304.83133,
#   'Air Temperature': 57.357044,
#   'Wind Speed': 7.4187655},
#  {'Timestamp': '2020-03-11T00:13:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5126475,
#   'Blade2 Actual': -0.47901517,
#   'Blade3 Actual': 0.05283314,
#   'Rotor Speed': 15.537004,
#   'State': 16,
#   'Active Power': 465.33334,
#   'Nacelle Position': 304.9084,
#   'Air Temperature': 57.34115,
#   'Wind Speed': 9.056112},
#  {'Timestamp': '2020-03-11T00:14:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.51025516,
#   'Blade2 Actual': -0.47674242,
#   'Blade3 Actual': 0.06547246,
#   'Rotor Speed': 15.217642,
#   'State': 16,
#   'Active Power': 465.4,
#   'Nacelle Position': 304.9854,
#   'Air Temperature': 57.325253,
#   'Wind Speed': 7.914674},
#  {'Timestamp': '2020-03-11T00:15:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5078628,
#   'Blade2 Actual': -0.4744697,
#   'Blade3 Actual': 0.078111775,
#   'Rotor Speed': 18.417603,
#   'State': 16,
#   'Active Power': 668.125,
#   'Nacelle Position': 305.06247,
#   'Air Temperature': 57.309357,
#   'Wind Speed': 9.064996},
#  {'Timestamp': '2020-03-11T00:16:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5054705,
#   'Blade2 Actual': -0.47219697,
#   'Blade3 Actual': 0.0907511,
#   'Rotor Speed': 18.88317,
#   'State': 16,
#   'Active Power': 836,
#   'Nacelle Position': 305.13953,
#   'Air Temperature': 57.29346,
#   'Wind Speed': 9.354413},
#  {'Timestamp': '2020-03-11T00:17:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.50307816,
#   'Blade2 Actual': -0.46992424,
#   'Blade3 Actual': 0.10339042,
#   'Rotor Speed': 19.937363,
#   'State': 16,
#   'Active Power': 1025,
#   'Nacelle Position': 305.21655,
#   'Air Temperature': 57.277565,
#   'Wind Speed': 10.39228},
#  {'Timestamp': '2020-03-11T00:18:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5006858,
#   'Blade2 Actual': -0.46765152,
#   'Blade3 Actual': 0.10534428,
#   'Rotor Speed': 19.595356,
#   'State': 16,
#   'Active Power': 1048,
#   'Nacelle Position': 305.2936,
#   'Air Temperature': 57.26167,
#   'Wind Speed': 10.257415},
#  {'Timestamp': '2020-03-11T00:19:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.49829346,
#   'Blade2 Actual': -0.4653788,
#   'Blade3 Actual': 0.084240034,
#   'Rotor Speed': 19.281563,
#   'State': 16,
#   'Active Power': 1150,
#   'Nacelle Position': 305.29858,
#   'Air Temperature': 57.245773,
#   'Wind Speed': 10.664617},
#  {'Timestamp': '2020-03-11T00:20:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4959011,
#   'Blade2 Actual': -0.46310607,
#   'Blade3 Actual': 0.063135795,
#   'Rotor Speed': 18.698137,
#   'State': 16,
#   'Active Power': 806.07404,
#   'Nacelle Position': 305.2521,
#   'Air Temperature': 57.229877,
#   'Wind Speed': 9.055866},
#  {'Timestamp': '2020-03-11T00:21:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.49350876,
#   'Blade2 Actual': -0.46083334,
#   'Blade3 Actual': 0.04203155,
#   'Rotor Speed': 19.523144,
#   'State': 16,
#   'Active Power': 1014,
#   'Nacelle Position': 305.2056,
#   'Air Temperature': 57.21398,
#   'Wind Speed': 10.535706},
#  {'Timestamp': '2020-03-11T00:22:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.49111643,
#   'Blade2 Actual': -0.45856062,
#   'Blade3 Actual': 0.020927308,
#   'Rotor Speed': 19.937809,
#   'State': 16,
#   'Active Power': 840,
#   'Nacelle Position': 305.15912,
#   'Air Temperature': 57.19809,
#   'Wind Speed': 8.929344},
#  {'Timestamp': '2020-03-11T00:23:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.48872408,
#   'Blade2 Actual': -0.4562879,
#   'Blade3 Actual': -0.0001769351,
#   'Rotor Speed': 19.423122,
#   'State': 16,
#   'Active Power': 965,
#   'Nacelle Position': 305.11264,
#   'Air Temperature': 57.182194,
#   'Wind Speed': 10.83228},
#  {'Timestamp': '2020-03-11T00:24:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.48633173,
#   'Blade2 Actual': -0.45401517,
#   'Blade3 Actual': -0.021281177,
#   'Rotor Speed': 19.183752,
#   'State': 16,
#   'Active Power': 878.5,
#   'Nacelle Position': 305.06613,
#   'Air Temperature': 57.166298,
#   'Wind Speed': 9.724257},
#  {'Timestamp': '2020-03-11T00:25:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.48393938,
#   'Blade2 Actual': -0.45174244,
#   'Blade3 Actual': -0.04238542,
#   'Rotor Speed': 19.680449,
#   'State': 16,
#   'Active Power': 1105,
#   'Nacelle Position': 305.01965,
#   'Air Temperature': 57.150402,
#   'Wind Speed': 10.495991},
#  {'Timestamp': '2020-03-11T00:26:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.48154706,
#   'Blade2 Actual': -0.4494697,
#   'Blade3 Actual': -0.06348966,
#   'Rotor Speed': 18.108139,
#   'State': 16,
#   'Active Power': 631,
#   'Nacelle Position': 304.97314,
#   'Air Temperature': 57.134506,
#   'Wind Speed': 8.704097},
#  {'Timestamp': '2020-03-11T00:27:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4791547,
#   'Blade2 Actual': -0.44719696,
#   'Blade3 Actual': -0.08459391,
#   'Rotor Speed': 18.230087,
#   'State': 16,
#   'Active Power': 779,
#   'Nacelle Position': 304.92667,
#   'Air Temperature': 57.11861,
#   'Wind Speed': 9.639395},
#  {'Timestamp': '2020-03-11T00:28:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.47676235,
#   'Blade2 Actual': -0.44492424,
#   'Blade3 Actual': -0.105698146,
#   'Rotor Speed': 16.403402,
#   'State': 16,
#   'Active Power': 554.7695,
#   'Nacelle Position': 304.88016,
#   'Air Temperature': 57.102715,
#   'Wind Speed': 7.5916076},
#  {'Timestamp': '2020-03-11T00:29:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.47437,
#   'Blade2 Actual': -0.4426515,
#   'Blade3 Actual': -0.12680238,
#   'Rotor Speed': 15.5169935,
#   'State': 16,
#   'Active Power': 425.9091,
#   'Nacelle Position': 304.83368,
#   'Air Temperature': 57.08682,
#   'Wind Speed': 8.137148},
#  {'Timestamp': '2020-03-11T00:30:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.47197768,
#   'Blade2 Actual': -0.4403788,
#   'Blade3 Actual': -0.14790663,
#   'Rotor Speed': 16.453241,
#   'State': 16,
#   'Active Power': 557.02563,
#   'Nacelle Position': 304.7872,
#   'Air Temperature': 57.070923,
#   'Wind Speed': 8.51282},
#  {'Timestamp': '2020-03-11T00:31:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.46958533,
#   'Blade2 Actual': -0.43810606,
#   'Blade3 Actual': -0.16901088,
#   'Rotor Speed': 15.68897,
#   'State': 16,
#   'Active Power': 415.85715,
#   'Nacelle Position': 304.7407,
#   'Air Temperature': 57.055027,
#   'Wind Speed': 8.027469},
#  {'Timestamp': '2020-03-11T00:32:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.46719298,
#   'Blade2 Actual': -0.43583333,
#   'Blade3 Actual': -0.19011512,
#   'Rotor Speed': 17.478582,
#   'State': 16,
#   'Active Power': 643.8182,
#   'Nacelle Position': 304.6942,
#   'Air Temperature': 57.03913,
#   'Wind Speed': 8.673249},
#  {'Timestamp': '2020-03-11T00:33:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.46480063,
#   'Blade2 Actual': -0.4335606,
#   'Blade3 Actual': -0.21121936,
#   'Rotor Speed': 16.25733,
#   'State': 16,
#   'Active Power': 527.31946,
#   'Nacelle Position': 304.6477,
#   'Air Temperature': 57.023235,
#   'Wind Speed': 7.867296},
#  {'Timestamp': '2020-03-11T00:34:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4624083,
#   'Blade2 Actual': -0.43128788,
#   'Blade3 Actual': -0.2323236,
#   'Rotor Speed': 15.948269,
#   'State': 16,
#   'Active Power': 450.3333,
#   'Nacelle Position': 304.60123,
#   'Air Temperature': 57.00734,
#   'Wind Speed': 8.643309},
#  {'Timestamp': '2020-03-11T00:35:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.46001595,
#   'Blade2 Actual': -0.42901516,
#   'Blade3 Actual': -0.25342783,
#   'Rotor Speed': 18.161884,
#   'State': 16,
#   'Active Power': 740.125,
#   'Nacelle Position': 304.55472,
#   'Air Temperature': 56.991444,
#   'Wind Speed': 9.205555},
#  {'Timestamp': '2020-03-11T00:36:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4576236,
#   'Blade2 Actual': -0.42674243,
#   'Blade3 Actual': -0.27453208,
#   'Rotor Speed': 19.397394,
#   'State': 16,
#   'Active Power': 915,
#   'Nacelle Position': 304.50824,
#   'Air Temperature': 56.975548,
#   'Wind Speed': 10.77532},
#  {'Timestamp': '2020-03-11T00:37:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.45523125,
#   'Blade2 Actual': -0.4244697,
#   'Blade3 Actual': -0.29563633,
#   'Rotor Speed': 15.17745,
#   'State': 16,
#   'Active Power': 417,
#   'Nacelle Position': 304.46176,
#   'Air Temperature': 56.959652,
#   'Wind Speed': 6.852071},
#  {'Timestamp': '2020-03-11T00:38:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4528389,
#   'Blade2 Actual': -0.42219695,
#   'Blade3 Actual': -0.31674057,
#   'Rotor Speed': 18.685774,
#   'State': 16,
#   'Active Power': 847.3333,
#   'Nacelle Position': 304.41525,
#   'Air Temperature': 56.943756,
#   'Wind Speed': 9.137125},
#  {'Timestamp': '2020-03-11T00:39:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.45044658,
#   'Blade2 Actual': -0.41992423,
#   'Blade3 Actual': -0.33784482,
#   'Rotor Speed': 15.375455,
#   'State': 16,
#   'Active Power': 415.3117,
#   'Nacelle Position': 304.36877,
#   'Air Temperature': 56.92786,
#   'Wind Speed': 7.073829},
#  {'Timestamp': '2020-03-11T00:40:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.44805422,
#   'Blade2 Actual': -0.4176515,
#   'Blade3 Actual': -0.35894907,
#   'Rotor Speed': 14.726716,
#   'State': 16,
#   'Active Power': 324.58334,
#   'Nacelle Position': 304.32227,
#   'Air Temperature': 56.911964,
#   'Wind Speed': 7.297011},
#  {'Timestamp': '2020-03-11T00:41:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.44566187,
#   'Blade2 Actual': -0.41537878,
#   'Blade3 Actual': -0.3800533,
#   'Rotor Speed': 16.251347,
#   'State': 16,
#   'Active Power': 517.6364,
#   'Nacelle Position': 298.46082,
#   'Air Temperature': 56.896072,
#   'Wind Speed': 8.054695},
#  {'Timestamp': '2020-03-11T00:42:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.44326952,
#   'Blade2 Actual': -0.41310605,
#   'Blade3 Actual': -0.40115753,
#   'Rotor Speed': 19.057812,
#   'State': 16,
#   'Active Power': 861.93195,
#   'Nacelle Position': 299.0011,
#   'Air Temperature': 56.880177,
#   'Wind Speed': 8.364735},
#  {'Timestamp': '2020-03-11T00:43:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4408772,
#   'Blade2 Actual': -0.41083333,
#   'Blade3 Actual': -0.42226177,
#   'Rotor Speed': 16.527735,
#   'State': 16,
#   'Active Power': 524,
#   'Nacelle Position': 299.54138,
#   'Air Temperature': 56.86428,
#   'Wind Speed': 7.494199},
#  {'Timestamp': '2020-03-11T00:44:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.6539432,
#   'Blade2 Actual': -0.6543758,
#   'Blade3 Actual': -0.59610635,
#   'Rotor Speed': 19.362652,
#   'State': 16,
#   'Active Power': 993.3333,
#   'Nacelle Position': 300.08163,
#   'Air Temperature': 56.848385,
#   'Wind Speed': 8.806425},
#  {'Timestamp': '2020-03-11T00:45:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.64356,
#   'Blade2 Actual': -0.64473426,
#   'Blade3 Actual': -0.5894314,
#   'Rotor Speed': 18.019535,
#   'State': 16,
#   'Active Power': 647.6,
#   'Nacelle Position': 300.62192,
#   'Air Temperature': 56.83249,
#   'Wind Speed': 7.61691},
#  {'Timestamp': '2020-03-11T00:46:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.6331768,
#   'Blade2 Actual': -0.63509274,
#   'Blade3 Actual': -0.5827565,
#   'Rotor Speed': 17.882421,
#   'State': 16,
#   'Active Power': 634.26666,
#   'Nacelle Position': 301.1622,
#   'Air Temperature': 56.816593,
#   'Wind Speed': 7.639665},
#  {'Timestamp': '2020-03-11T00:47:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.6227936,
#   'Blade2 Actual': -0.6254512,
#   'Blade3 Actual': -0.5760816,
#   'Rotor Speed': 15.406586,
#   'State': 16,
#   'Active Power': 455.07724,
#   'Nacelle Position': 301.70248,
#   'Air Temperature': 56.800697,
#   'Wind Speed': 8.531841},
#  {'Timestamp': '2020-03-11T00:48:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.61241037,
#   'Blade2 Actual': -0.6158096,
#   'Blade3 Actual': -0.5694067,
#   'Rotor Speed': 13.981469,
#   'State': 16,
#   'Active Power': 325.6536,
#   'Nacelle Position': 302.24274,
#   'Air Temperature': 56.7848,
#   'Wind Speed': 7.555406},
#  {'Timestamp': '2020-03-11T00:49:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.6020272,
#   'Blade2 Actual': -0.6061681,
#   'Blade3 Actual': -0.5627318,
#   'Rotor Speed': 12.239435,
#   'State': 16,
#   'Active Power': 173.125,
#   'Nacelle Position': 302.78302,
#   'Air Temperature': 56.768906,
#   'Wind Speed': 5.175661},
#  {'Timestamp': '2020-03-11T00:50:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.591644,
#   'Blade2 Actual': -0.59652656,
#   'Blade3 Actual': -0.55605686,
#   'Rotor Speed': 14.008628,
#   'State': 16,
#   'Active Power': 283.9524,
#   'Nacelle Position': 303.3233,
#   'Air Temperature': 56.75301,
#   'Wind Speed': 7.973207},
#  {'Timestamp': '2020-03-11T00:51:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5812608,
#   'Blade2 Actual': -0.58688504,
#   'Blade3 Actual': -0.549382,
#   'Rotor Speed': 15.484644,
#   'State': 16,
#   'Active Power': 423.44446,
#   'Nacelle Position': 303.86356,
#   'Air Temperature': 56.737114,
#   'Wind Speed': 7.8772244},
#  {'Timestamp': '2020-03-11T00:52:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5708776,
#   'Blade2 Actual': -0.5772435,
#   'Blade3 Actual': -0.542707,
#   'Rotor Speed': 15.236604,
#   'State': 16,
#   'Active Power': 368.64545,
#   'Nacelle Position': 304.40384,
#   'Air Temperature': 56.72122,
#   'Wind Speed': 6.302245},
#  {'Timestamp': '2020-03-11T00:53:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5604944,
#   'Blade2 Actual': -0.567602,
#   'Blade3 Actual': -0.53603214,
#   'Rotor Speed': 14.489103,
#   'State': 16,
#   'Active Power': 299.48148,
#   'Nacelle Position': 304.94412,
#   'Air Temperature': 56.705322,
#   'Wind Speed': 6.16989},
#  {'Timestamp': '2020-03-11T00:54:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.55011123,
#   'Blade2 Actual': -0.55796045,
#   'Blade3 Actual': -0.52935725,
#   'Rotor Speed': 15.753471,
#   'State': 16,
#   'Active Power': 483.88892,
#   'Nacelle Position': 305.4844,
#   'Air Temperature': 56.689426,
#   'Wind Speed': 6.695298},
#  {'Timestamp': '2020-03-11T00:55:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.53972805,
#   'Blade2 Actual': -0.54831886,
#   'Blade3 Actual': -0.5226823,
#   'Rotor Speed': 15.63658,
#   'State': 16,
#   'Active Power': 468.7143,
#   'Nacelle Position': 306.02466,
#   'Air Temperature': 56.67353,
#   'Wind Speed': 7.495495},
#  {'Timestamp': '2020-03-11T00:56:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.52934486,
#   'Blade2 Actual': -0.53867733,
#   'Blade3 Actual': -0.5160074,
#   'Rotor Speed': 14.719485,
#   'State': 16,
#   'Active Power': 326.32632,
#   'Nacelle Position': 306.56494,
#   'Air Temperature': 56.657635,
#   'Wind Speed': 6.8200154},
#  {'Timestamp': '2020-03-11T00:57:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5138983,
#   'Blade2 Actual': -0.53474575,
#   'Blade3 Actual': -0.5142373,
#   'Rotor Speed': 19.047203,
#   'State': 16,
#   'Active Power': 944,
#   'Nacelle Position': 307.10522,
#   'Air Temperature': 56.64174,
#   'Wind Speed': 9.838441},
#  {'Timestamp': '2020-03-11T00:58:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5674545,
#   'Blade2 Actual': -0.6365454,
#   'Blade3 Actual': -0.5674545,
#   'Rotor Speed': 19.949583,
#   'State': 16,
#   'Active Power': 1164.5,
#   'Nacelle Position': 307.6455,
#   'Air Temperature': 56.625843,
#   'Wind Speed': 9.746135},
#  {'Timestamp': '2020-03-11T00:59:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.121202014,
#   'Blade2 Actual': -0.16444446,
#   'Blade3 Actual': -0.124545425,
#   'Rotor Speed': 19.78736,
#   'State': 16,
#   'Active Power': 1052,
#   'Nacelle Position': 308.18576,
#   'Air Temperature': 56.609947,
#   'Wind Speed': 10.349795},
#  {'Timestamp': '2020-03-11T01:00:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.56121814,
#   'Blade2 Actual': -0.61950004,
#   'Blade3 Actual': -0.56140906,
#   'Rotor Speed': 17.837759,
#   'State': 16,
#   'Active Power': 628.4545,
#   'Nacelle Position': 308.72604,
#   'Air Temperature': 56.594055,
#   'Wind Speed': 8.43812},
#  {'Timestamp': '2020-03-11T01:01:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.55285454,
#   'Blade2 Actual': -0.60950005,
#   'Blade3 Actual': -0.55322725,
#   'Rotor Speed': 18.630371,
#   'State': 16,
#   'Active Power': 792.6667,
#   'Nacelle Position': 309.26633,
#   'Air Temperature': 56.57816,
#   'Wind Speed': 8.245358},
#  {'Timestamp': '2020-03-11T01:02:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5444909,
#   'Blade2 Actual': -0.59950006,
#   'Blade3 Actual': -0.5450454,
#   'Rotor Speed': 16.485521,
#   'State': 16,
#   'Active Power': 561,
#   'Nacelle Position': 309.80658,
#   'Air Temperature': 56.562263,
#   'Wind Speed': 7.4704394},
#  {'Timestamp': '2020-03-11T01:03:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5361272,
#   'Blade2 Actual': -0.5895,
#   'Blade3 Actual': -0.53686357,
#   'Rotor Speed': 19.052998,
#   'State': 16,
#   'Active Power': 833.8889,
#   'Nacelle Position': 310.34686,
#   'Air Temperature': 56.546368,
#   'Wind Speed': 8.238677},
#  {'Timestamp': '2020-03-11T01:04:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5277636,
#   'Blade2 Actual': -0.5795,
#   'Blade3 Actual': -0.52868176,
#   'Rotor Speed': 16.703201,
#   'State': 16,
#   'Active Power': 578.39996,
#   'Nacelle Position': 310.88715,
#   'Air Temperature': 56.53047,
#   'Wind Speed': 8.267839},
#  {'Timestamp': '2020-03-11T01:05:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.51939994,
#   'Blade2 Actual': -0.5695,
#   'Blade3 Actual': -0.52049994,
#   'Rotor Speed': 16.961369,
#   'State': 16,
#   'Active Power': 582,
#   'Nacelle Position': 311.42743,
#   'Air Temperature': 56.514576,
#   'Wind Speed': 7.871828},
#  {'Timestamp': '2020-03-11T01:06:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.51103634,
#   'Blade2 Actual': -0.55950004,
#   'Blade3 Actual': -0.51231813,
#   'Rotor Speed': 15.665928,
#   'State': 16,
#   'Active Power': 426.4,
#   'Nacelle Position': 311.96768,
#   'Air Temperature': 56.49868,
#   'Wind Speed': 7.816232},
#  {'Timestamp': '2020-03-11T01:07:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5026727,
#   'Blade2 Actual': -0.54950005,
#   'Blade3 Actual': -0.5041363,
#   'Rotor Speed': 16.362595,
#   'State': 16,
#   'Active Power': 464.53845,
#   'Nacelle Position': 312.50797,
#   'Air Temperature': 56.482784,
#   'Wind Speed': 7.866605},
#  {'Timestamp': '2020-03-11T01:08:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.49430904,
#   'Blade2 Actual': -0.53950006,
#   'Blade3 Actual': -0.4959545,
#   'Rotor Speed': 15.958397,
#   'State': 16,
#   'Active Power': 465.90775,
#   'Nacelle Position': 313.04825,
#   'Air Temperature': 56.46689,
#   'Wind Speed': 7.1648273},
#  {'Timestamp': '2020-03-11T01:09:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4859454,
#   'Blade2 Actual': -0.5295,
#   'Blade3 Actual': -0.48777267,
#   'Rotor Speed': 15.95221,
#   'State': 16,
#   'Active Power': 461.27036,
#   'Nacelle Position': 313.58853,
#   'Air Temperature': 56.450993,
#   'Wind Speed': 8.556231},
#  {'Timestamp': '2020-03-11T01:10:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.47758177,
#   'Blade2 Actual': -0.5195,
#   'Blade3 Actual': -0.47959086,
#   'Rotor Speed': 15.306699,
#   'State': 16,
#   'Active Power': 379.66666,
#   'Nacelle Position': 314.12878,
#   'Air Temperature': 56.435097,
#   'Wind Speed': 7.4354835},
#  {'Timestamp': '2020-03-11T01:11:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.46921813,
#   'Blade2 Actual': -0.5095,
#   'Blade3 Actual': -0.47140905,
#   'Rotor Speed': 16.316051,
#   'State': 16,
#   'Active Power': 516.45264,
#   'Nacelle Position': 314.66907,
#   'Air Temperature': 56.4192,
#   'Wind Speed': 7.4219556},
#  {'Timestamp': '2020-03-11T01:12:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4608545,
#   'Blade2 Actual': -0.49950004,
#   'Blade3 Actual': -0.46322724,
#   'Rotor Speed': 17.008465,
#   'State': 16,
#   'Active Power': 596.6909,
#   'Nacelle Position': 315.20935,
#   'Air Temperature': 56.403305,
#   'Wind Speed': 8.514627},
#  {'Timestamp': '2020-03-11T01:13:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.45249087,
#   'Blade2 Actual': -0.48950002,
#   'Blade3 Actual': -0.45504543,
#   'Rotor Speed': 14.633168,
#   'State': 16,
#   'Active Power': 374.188,
#   'Nacelle Position': 315.74963,
#   'Air Temperature': 56.38741,
#   'Wind Speed': 6.8615556},
#  {'Timestamp': '2020-03-11T01:14:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.44412723,
#   'Blade2 Actual': -0.47950003,
#   'Blade3 Actual': -0.4468636,
#   'Rotor Speed': 15.091126,
#   'State': 16,
#   'Active Power': 399.2,
#   'Nacelle Position': 316.2899,
#   'Air Temperature': 56.371513,
#   'Wind Speed': 7.620718},
#  {'Timestamp': '2020-03-11T01:15:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4357636,
#   'Blade2 Actual': -0.4695,
#   'Blade3 Actual': -0.43868178,
#   'Rotor Speed': 18.965504,
#   'State': 16,
#   'Active Power': 846.5,
#   'Nacelle Position': 316.83017,
#   'Air Temperature': 56.355618,
#   'Wind Speed': 9.120808},
#  {'Timestamp': '2020-03-11T01:16:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.42739996,
#   'Blade2 Actual': -0.4595,
#   'Blade3 Actual': -0.43049997,
#   'Rotor Speed': 19.493,
#   'State': 16,
#   'Active Power': 902,
#   'Nacelle Position': 317.37045,
#   'Air Temperature': 56.33972,
#   'Wind Speed': 11.214254},
#  {'Timestamp': '2020-03-11T01:17:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.41903633,
#   'Blade2 Actual': -0.44950002,
#   'Blade3 Actual': -0.42231816,
#   'Rotor Speed': 15.265365,
#   'State': 16,
#   'Active Power': 410.35,
#   'Nacelle Position': 317.9107,
#   'Air Temperature': 56.323826,
#   'Wind Speed': 7.692697},
#  {'Timestamp': '2020-03-11T01:18:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4106727,
#   'Blade2 Actual': -0.4395,
#   'Blade3 Actual': -0.41413635,
#   'Rotor Speed': 16.697168,
#   'State': 16,
#   'Active Power': 514.75,
#   'Nacelle Position': 318.28198,
#   'Air Temperature': 56.307934,
#   'Wind Speed': 7.866577},
#  {'Timestamp': '2020-03-11T01:19:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.40230906,
#   'Blade2 Actual': -0.4295,
#   'Blade3 Actual': -0.40595454,
#   'Rotor Speed': 17.418602,
#   'State': 16,
#   'Active Power': 637.4,
#   'Nacelle Position': 318.28854,
#   'Air Temperature': 56.292038,
#   'Wind Speed': 7.150182},
#  {'Timestamp': '2020-03-11T01:20:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.39394543,
#   'Blade2 Actual': -0.4195,
#   'Blade3 Actual': -0.39777273,
#   'Rotor Speed': 15.982309,
#   'State': 16,
#   'Active Power': 468.1875,
#   'Nacelle Position': 318.29507,
#   'Air Temperature': 56.276142,
#   'Wind Speed': 7.036914},
#  {'Timestamp': '2020-03-11T01:21:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.3855818,
#   'Blade2 Actual': -0.4095,
#   'Blade3 Actual': -0.3895909,
#   'Rotor Speed': 16.224401,
#   'State': 16,
#   'Active Power': 489.03424,
#   'Nacelle Position': 318.30167,
#   'Air Temperature': 56.260246,
#   'Wind Speed': 7.712471},
#  {'Timestamp': '2020-03-11T01:22:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.37721816,
#   'Blade2 Actual': -0.3995,
#   'Blade3 Actual': -0.38140905,
#   'Rotor Speed': 12.89115,
#   'State': 16,
#   'Active Power': 250,
#   'Nacelle Position': 318.30823,
#   'Air Temperature': 56.244354,
#   'Wind Speed': 6.1752954},
#  {'Timestamp': '2020-03-11T01:23:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.36885452,
#   'Blade2 Actual': -0.38950002,
#   'Blade3 Actual': -0.37322727,
#   'Rotor Speed': 17.421013,
#   'State': 16,
#   'Active Power': 692.5,
#   'Nacelle Position': 318.31476,
#   'Air Temperature': 56.228455,
#   'Wind Speed': 9.145708},
#  {'Timestamp': '2020-03-11T01:24:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.3604909,
#   'Blade2 Actual': -0.3795,
#   'Blade3 Actual': -0.36504543,
#   'Rotor Speed': 16.10623,
#   'State': 16,
#   'Active Power': 509.36365,
#   'Nacelle Position': 318.32132,
#   'Air Temperature': 56.21256,
#   'Wind Speed': 6.859447},
#  {'Timestamp': '2020-03-11T01:25:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.35212725,
#   'Blade2 Actual': -0.3695,
#   'Blade3 Actual': -0.35686362,
#   'Rotor Speed': 14.791582,
#   'State': 16,
#   'Active Power': 358.95657,
#   'Nacelle Position': 318.32788,
#   'Air Temperature': 56.196663,
#   'Wind Speed': 6.623848},
#  {'Timestamp': '2020-03-11T01:26:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.34376362,
#   'Blade2 Actual': -0.35950002,
#   'Blade3 Actual': -0.3486818,
#   'Rotor Speed': 14.90711,
#   'State': 16,
#   'Active Power': 365,
#   'Nacelle Position': 318.33444,
#   'Air Temperature': 56.180767,
#   'Wind Speed': 7.584589},
#  {'Timestamp': '2020-03-11T01:27:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.3354,
#   'Blade2 Actual': -0.3495,
#   'Blade3 Actual': -0.3405,
#   'Rotor Speed': 15.006964,
#   'State': 16,
#   'Active Power': 409.06592,
#   'Nacelle Position': 318.341,
#   'Air Temperature': 56.16487,
#   'Wind Speed': 7.8472586},
#  {'Timestamp': '2020-03-11T01:28:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.32703632,
#   'Blade2 Actual': -0.3395,
#   'Blade3 Actual': -0.3323182,
#   'Rotor Speed': 14.472185,
#   'State': 16,
#   'Active Power': 344.36194,
#   'Nacelle Position': 318.34756,
#   'Air Temperature': 56.14898,
#   'Wind Speed': 7.024034},
#  {'Timestamp': '2020-03-11T01:29:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.31867272,
#   'Blade2 Actual': -0.32950002,
#   'Blade3 Actual': -0.32413635,
#   'Rotor Speed': 13.682327,
#   'State': 16,
#   'Active Power': 290.4148,
#   'Nacelle Position': 318.35413,
#   'Air Temperature': 56.133083,
#   'Wind Speed': 7.1455674},
#  {'Timestamp': '2020-03-11T01:30:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.31030908,
#   'Blade2 Actual': -0.3195,
#   'Blade3 Actual': -0.31595454,
#   'Rotor Speed': 14.281012,
#   'State': 16,
#   'Active Power': 312.2121,
#   'Nacelle Position': 318.3607,
#   'Air Temperature': 56.117188,
#   'Wind Speed': 6.896959},
#  {'Timestamp': '2020-03-11T01:31:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.30194545,
#   'Blade2 Actual': -0.3095,
#   'Blade3 Actual': -0.3077727,
#   'Rotor Speed': 15.075036,
#   'State': 16,
#   'Active Power': 373.6667,
#   'Nacelle Position': 318.36725,
#   'Air Temperature': 56.101288,
#   'Wind Speed': 7.658148},
#  {'Timestamp': '2020-03-11T01:32:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.29358178,
#   'Blade2 Actual': -0.2995,
#   'Blade3 Actual': -0.29959092,
#   'Rotor Speed': 14.692858,
#   'State': 16,
#   'Active Power': 348.73334,
#   'Nacelle Position': 318.3738,
#   'Air Temperature': 56.085392,
#   'Wind Speed': 7.0564876},
#  {'Timestamp': '2020-03-11T01:33:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.28521815,
#   'Blade2 Actual': -0.2895,
#   'Blade3 Actual': -0.29140908,
#   'Rotor Speed': 16.218405,
#   'State': 16,
#   'Active Power': 461.55554,
#   'Nacelle Position': 318.38037,
#   'Air Temperature': 56.0695,
#   'Wind Speed': 7.301932},
#  {'Timestamp': '2020-03-11T01:34:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.27685452,
#   'Blade2 Actual': -0.2795,
#   'Blade3 Actual': -0.28322726,
#   'Rotor Speed': 15.583151,
#   'State': 16,
#   'Active Power': 455.6875,
#   'Nacelle Position': 318.38693,
#   'Air Temperature': 56.053604,
#   'Wind Speed': 7.54557},
#  {'Timestamp': '2020-03-11T01:35:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.26849088,
#   'Blade2 Actual': -0.26950002,
#   'Blade3 Actual': -0.27504545,
#   'Rotor Speed': 17.447062,
#   'State': 16,
#   'Active Power': 635.78125,
#   'Nacelle Position': 318.3935,
#   'Air Temperature': 56.03771,
#   'Wind Speed': 8.659566},
#  {'Timestamp': '2020-03-11T01:36:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.26012725,
#   'Blade2 Actual': -0.25950003,
#   'Blade3 Actual': -0.26686364,
#   'Rotor Speed': 17.545061,
#   'State': 16,
#   'Active Power': 662.1428,
#   'Nacelle Position': 318.40002,
#   'Air Temperature': 56.021812,
#   'Wind Speed': 8.136973},
#  {'Timestamp': '2020-03-11T01:37:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.2517636,
#   'Blade2 Actual': -0.2495,
#   'Blade3 Actual': -0.2586818,
#   'Rotor Speed': 15.754263,
#   'State': 16,
#   'Active Power': 406.62756,
#   'Nacelle Position': 318.4066,
#   'Air Temperature': 56.005917,
#   'Wind Speed': 7.713695},
#  {'Timestamp': '2020-03-11T01:38:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.24339998,
#   'Blade2 Actual': -0.2395,
#   'Blade3 Actual': -0.25049996,
#   'Rotor Speed': 17.1977,
#   'State': 16,
#   'Active Power': 552.93335,
#   'Nacelle Position': 318.41315,
#   'Air Temperature': 55.99002,
#   'Wind Speed': 9.035572},
#  {'Timestamp': '2020-03-11T01:39:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.23503634,
#   'Blade2 Actual': -0.22950001,
#   'Blade3 Actual': -0.24231817,
#   'Rotor Speed': 18.353292,
#   'State': 16,
#   'Active Power': 682.7006,
#   'Nacelle Position': 318.4197,
#   'Air Temperature': 55.974125,
#   'Wind Speed': 8.034049},
#  {'Timestamp': '2020-03-11T01:40:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.22667271,
#   'Blade2 Actual': -0.2195,
#   'Blade3 Actual': -0.23413636,
#   'Rotor Speed': 16.539982,
#   'State': 16,
#   'Active Power': 501.82053,
#   'Nacelle Position': 318.42627,
#   'Air Temperature': 55.95823,
#   'Wind Speed': 8.233949},
#  {'Timestamp': '2020-03-11T01:41:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.21830907,
#   'Blade2 Actual': -0.2095,
#   'Blade3 Actual': -0.22595453,
#   'Rotor Speed': 18.059977,
#   'State': 16,
#   'Active Power': 692.25385,
#   'Nacelle Position': 318.43286,
#   'Air Temperature': 55.942337,
#   'Wind Speed': 8.120652},
#  {'Timestamp': '2020-03-11T01:42:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.20994544,
#   'Blade2 Actual': -0.19950001,
#   'Blade3 Actual': -0.21777272,
#   'Rotor Speed': 16.269253,
#   'State': 16,
#   'Active Power': 497.66666,
#   'Nacelle Position': 318.4394,
#   'Air Temperature': 55.926437,
#   'Wind Speed': 7.4591055},
#  {'Timestamp': '2020-03-11T01:43:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.2015818,
#   'Blade2 Actual': -0.1895,
#   'Blade3 Actual': -0.2095909,
#   'Rotor Speed': 16.556664,
#   'State': 16,
#   'Active Power': 581.6667,
#   'Nacelle Position': 318.44595,
#   'Air Temperature': 55.91054,
#   'Wind Speed': 7.976098},
#  {'Timestamp': '2020-03-11T01:44:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.19321817,
#   'Blade2 Actual': -0.1795,
#   'Blade3 Actual': -0.20140909,
#   'Rotor Speed': 17.406681,
#   'State': 16,
#   'Active Power': 645.1786,
#   'Nacelle Position': 318.4525,
#   'Air Temperature': 55.894646,
#   'Wind Speed': 8.6611595},
#  {'Timestamp': '2020-03-11T01:45:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.18485454,
#   'Blade2 Actual': -0.1695,
#   'Blade3 Actual': -0.19322726,
#   'Rotor Speed': 17.353558,
#   'State': 16,
#   'Active Power': 614.7143,
#   'Nacelle Position': 318.45905,
#   'Air Temperature': 55.878754,
#   'Wind Speed': 8.972319},
#  {'Timestamp': '2020-03-11T01:46:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.1764909,
#   'Blade2 Actual': -0.1595,
#   'Blade3 Actual': -0.18504545,
#   'Rotor Speed': 17.17227,
#   'State': 16,
#   'Active Power': 638.08527,
#   'Nacelle Position': 318.46564,
#   'Air Temperature': 55.862854,
#   'Wind Speed': 8.888674},
#  {'Timestamp': '2020-03-11T01:47:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.16812727,
#   'Blade2 Actual': -0.1495,
#   'Blade3 Actual': -0.17686364,
#   'Rotor Speed': 15.739916,
#   'State': 16,
#   'Active Power': 481.875,
#   'Nacelle Position': 318.4722,
#   'Air Temperature': 55.846962,
#   'Wind Speed': 8.075142},
#  {'Timestamp': '2020-03-11T01:48:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.15976363,
#   'Blade2 Actual': -0.1395,
#   'Blade3 Actual': -0.16868182,
#   'Rotor Speed': 16.241062,
#   'State': 16,
#   'Active Power': 472.87878,
#   'Nacelle Position': 318.47876,
#   'Air Temperature': 55.831066,
#   'Wind Speed': 8.000744},
#  {'Timestamp': '2020-03-11T01:49:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.1514,
#   'Blade2 Actual': -0.1295,
#   'Blade3 Actual': -0.16049999,
#   'Rotor Speed': 17.285156,
#   'State': 16,
#   'Active Power': 599,
#   'Nacelle Position': 318.48532,
#   'Air Temperature': 55.81517,
#   'Wind Speed': 8.851857},
#  {'Timestamp': '2020-03-11T01:50:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.14303637,
#   'Blade2 Actual': -0.1195,
#   'Blade3 Actual': -0.15231818,
#   'Rotor Speed': 16.388258,
#   'State': 16,
#   'Active Power': 524.8397,
#   'Nacelle Position': 318.49188,
#   'Air Temperature': 55.799274,
#   'Wind Speed': 7.790982},
#  {'Timestamp': '2020-03-11T01:51:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.13467273,
#   'Blade2 Actual': -0.1095,
#   'Blade3 Actual': -0.14413635,
#   'Rotor Speed': 17.178934,
#   'State': 16,
#   'Active Power': 579.5,
#   'Nacelle Position': 318.49844,
#   'Air Temperature': 55.78338,
#   'Wind Speed': 7.592972},
#  {'Timestamp': '2020-03-11T01:52:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.12630908,
#   'Blade2 Actual': -0.0995,
#   'Blade3 Actual': -0.13595454,
#   'Rotor Speed': 15.311303,
#   'State': 16,
#   'Active Power': 394,
#   'Nacelle Position': 318.50497,
#   'Air Temperature': 55.767483,
#   'Wind Speed': 7.964965},
#  {'Timestamp': '2020-03-11T01:53:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.117945455,
#   'Blade2 Actual': -0.089499995,
#   'Blade3 Actual': -0.12777272,
#   'Rotor Speed': 19.05038,
#   'State': 16,
#   'Active Power': 853.45,
#   'Nacelle Position': 318.51154,
#   'Air Temperature': 55.751587,
#   'Wind Speed': 9.267243},
#  {'Timestamp': '2020-03-11T01:54:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.61,
#   'Blade2 Actual': -0.6,
#   'Blade3 Actual': -0.65,
#   'Rotor Speed': 19.180521,
#   'State': 16,
#   'Active Power': 1131,
#   'Nacelle Position': 318.5181,
#   'Air Temperature': 55.73569,
#   'Wind Speed': 8.254207},
#  {'Timestamp': '2020-03-11T01:55:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5988149,
#   'Blade2 Actual': -0.5900133,
#   'Blade3 Actual': -0.63561916,
#   'Rotor Speed': 15.292293,
#   'State': 16,
#   'Active Power': 379.35715,
#   'Nacelle Position': 318.52466,
#   'Air Temperature': 55.719795,
#   'Wind Speed': 6.962543},
#  {'Timestamp': '2020-03-11T01:56:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.58762985,
#   'Blade2 Actual': -0.5800266,
#   'Blade3 Actual': -0.62123835,
#   'Rotor Speed': 16.915508,
#   'State': 16,
#   'Active Power': 604.1111,
#   'Nacelle Position': 318.53122,
#   'Air Temperature': 55.7039,
#   'Wind Speed': 8.769629},
#  {'Timestamp': '2020-03-11T01:57:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.57644475,
#   'Blade2 Actual': -0.57004,
#   'Blade3 Actual': -0.6068575,
#   'Rotor Speed': 18.635288,
#   'State': 16,
#   'Active Power': 809.4645,
#   'Nacelle Position': 318.53778,
#   'Air Temperature': 55.688004,
#   'Wind Speed': 9.988848},
#  {'Timestamp': '2020-03-11T01:58:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5652597,
#   'Blade2 Actual': -0.5600533,
#   'Blade3 Actual': -0.59247667,
#   'Rotor Speed': 18.03521,
#   'State': 16,
#   'Active Power': 753.9,
#   'Nacelle Position': 318.54434,
#   'Air Temperature': 55.672108,
#   'Wind Speed': 9.663978},
#  {'Timestamp': '2020-03-11T01:59:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5540746,
#   'Blade2 Actual': -0.5500666,
#   'Blade3 Actual': -0.57809585,
#   'Rotor Speed': 17.375381,
#   'State': 16,
#   'Active Power': 613.72156,
#   'Nacelle Position': 318.5509,
#   'Air Temperature': 55.65621,
#   'Wind Speed': 8.289762},
#  {'Timestamp': '2020-03-11T02:00:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5428895,
#   'Blade2 Actual': -0.5400799,
#   'Blade3 Actual': -0.56371504,
#   'Rotor Speed': 15.812452,
#   'State': 16,
#   'Active Power': 452.57016,
#   'Nacelle Position': 318.55746,
#   'Air Temperature': 55.640316,
#   'Wind Speed': 7.813587},
#  {'Timestamp': '2020-03-11T02:01:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5317044,
#   'Blade2 Actual': -0.53009325,
#   'Blade3 Actual': -0.5493342,
#   'Rotor Speed': 15.13586,
#   'State': 16,
#   'Active Power': 363.71875,
#   'Nacelle Position': 318.56403,
#   'Air Temperature': 55.62442,
#   'Wind Speed': 6.793152},
#  {'Timestamp': '2020-03-11T02:02:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5205194,
#   'Blade2 Actual': -0.52010655,
#   'Blade3 Actual': -0.53495336,
#   'Rotor Speed': 16.23469,
#   'State': 16,
#   'Active Power': 502.9238,
#   'Nacelle Position': 318.57056,
#   'Air Temperature': 55.623253,
#   'Wind Speed': 7.46075},
#  {'Timestamp': '2020-03-11T02:03:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5093342,
#   'Blade2 Actual': -0.51011986,
#   'Blade3 Actual': -0.52057254,
#   'Rotor Speed': 16.47772,
#   'State': 16,
#   'Active Power': 567.3889,
#   'Nacelle Position': 318.57715,
#   'Air Temperature': 55.644184,
#   'Wind Speed': 7.874722},
#  {'Timestamp': '2020-03-11T02:04:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.49814916,
#   'Blade2 Actual': -0.50013316,
#   'Blade3 Actual': -0.50619173,
#   'Rotor Speed': 16.829939,
#   'State': 16,
#   'Active Power': 526.3571,
#   'Nacelle Position': 318.58368,
#   'Air Temperature': 55.66511,
#   'Wind Speed': 8.208897},
#  {'Timestamp': '2020-03-11T02:05:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.48696405,
#   'Blade2 Actual': -0.4901465,
#   'Blade3 Actual': -0.4918109,
#   'Rotor Speed': 16.252228,
#   'State': 16,
#   'Active Power': 482.93332,
#   'Nacelle Position': 318.59027,
#   'Air Temperature': 55.68604,
#   'Wind Speed': 8.272682},
#  {'Timestamp': '2020-03-11T02:06:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.47577897,
#   'Blade2 Actual': -0.4801598,
#   'Blade3 Actual': -0.47743008,
#   'Rotor Speed': 15.843556,
#   'State': 16,
#   'Active Power': 425.47543,
#   'Nacelle Position': 318.5968,
#   'Air Temperature': 55.70697,
#   'Wind Speed': 7.785026},
#  {'Timestamp': '2020-03-11T02:07:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4645939,
#   'Blade2 Actual': -0.47017312,
#   'Blade3 Actual': -0.46304926,
#   'Rotor Speed': 17.006645,
#   'State': 16,
#   'Active Power': 590.9375,
#   'Nacelle Position': 318.60336,
#   'Air Temperature': 55.727898,
#   'Wind Speed': 8.136515},
#  {'Timestamp': '2020-03-11T02:08:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.4534088,
#   'Blade2 Actual': -0.46018642,
#   'Blade3 Actual': -0.44866842,
#   'Rotor Speed': 16.552147,
#   'State': 16,
#   'Active Power': 503.88235,
#   'Nacelle Position': 318.60992,
#   'Air Temperature': 55.748825,
#   'Wind Speed': 8.866585},
#  {'Timestamp': '2020-03-11T02:09:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.44222373,
#   'Blade2 Actual': -0.45019975,
#   'Blade3 Actual': -0.4342876,
#   'Rotor Speed': 17.62547,
#   'State': 16,
#   'Active Power': 617.4625,
#   'Nacelle Position': 318.6165,
#   'Air Temperature': 55.769756,
#   'Wind Speed': 8.323166},
#  {'Timestamp': '2020-03-11T02:10:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.43103862,
#   'Blade2 Actual': -0.44021305,
#   'Blade3 Actual': -0.41990677,
#   'Rotor Speed': 16.873175,
#   'State': 16,
#   'Active Power': 585.63635,
#   'Nacelle Position': 318.62305,
#   'Air Temperature': 55.790684,
#   'Wind Speed': 8.515188},
#  {'Timestamp': '2020-03-11T02:11:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.41985354,
#   'Blade2 Actual': -0.43022636,
#   'Blade3 Actual': -0.40552595,
#   'Rotor Speed': 17.361008,
#   'State': 16,
#   'Active Power': 607,
#   'Nacelle Position': 318.6296,
#   'Air Temperature': 55.81161,
#   'Wind Speed': 8.457671},
#  {'Timestamp': '2020-03-11T02:12:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.40866846,
#   'Blade2 Actual': -0.4202397,
#   'Blade3 Actual': -0.3911451,
#   'Rotor Speed': 17.207039,
#   'State': 16,
#   'Active Power': 619.5,
#   'Nacelle Position': 318.63617,
#   'Air Temperature': 55.832542,
#   'Wind Speed': 8.842422},
#  {'Timestamp': '2020-03-11T02:13:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.39748338,
#   'Blade2 Actual': -0.410253,
#   'Blade3 Actual': -0.3767643,
#   'Rotor Speed': 18.01716,
#   'State': 16,
#   'Active Power': 700.5,
#   'Nacelle Position': 318.64273,
#   'Air Temperature': 55.85347,
#   'Wind Speed': 8.448736},
#  {'Timestamp': '2020-03-11T02:14:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.38629827,
#   'Blade2 Actual': -0.40026632,
#   'Blade3 Actual': -0.36238346,
#   'Rotor Speed': 18.216528,
#   'State': 16,
#   'Active Power': 662.96747,
#   'Nacelle Position': 318.6493,
#   'Air Temperature': 55.874397,
#   'Wind Speed': 9.053539},
#  {'Timestamp': '2020-03-11T02:15:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.3751132,
#   'Blade2 Actual': -0.39027962,
#   'Blade3 Actual': -0.34800264,
#   'Rotor Speed': 17.342543,
#   'State': 16,
#   'Active Power': 586,
#   'Nacelle Position': 318.65585,
#   'Air Temperature': 55.895325,
#   'Wind Speed': 7.410234},
#  {'Timestamp': '2020-03-11T02:16:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.3639281,
#   'Blade2 Actual': -0.38029295,
#   'Blade3 Actual': -0.33362183,
#   'Rotor Speed': 17.355864,
#   'State': 16,
#   'Active Power': 602.35297,
#   'Nacelle Position': 318.6624,
#   'Air Temperature': 55.916256,
#   'Wind Speed': 8.17232},
#  {'Timestamp': '2020-03-11T02:17:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.35274303,
#   'Blade2 Actual': -0.37030625,
#   'Blade3 Actual': -0.31924102,
#   'Rotor Speed': 16.644094,
#   'State': 16,
#   'Active Power': 514,
#   'Nacelle Position': 318.66898,
#   'Air Temperature': 55.937183,
#   'Wind Speed': 6.884979},
#  {'Timestamp': '2020-03-11T02:18:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.34155792,
#   'Blade2 Actual': -0.36031955,
#   'Blade3 Actual': -0.30486017,
#   'Rotor Speed': 18.223217,
#   'State': 16,
#   'Active Power': 681.8889,
#   'Nacelle Position': 318.67554,
#   'Air Temperature': 55.958115,
#   'Wind Speed': 7.9938564},
#  {'Timestamp': '2020-03-11T02:19:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.33037284,
#   'Blade2 Actual': -0.3503329,
#   'Blade3 Actual': -0.29047936,
#   'Rotor Speed': 19.379564,
#   'State': 16,
#   'Active Power': 891,
#   'Nacelle Position': 318.6821,
#   'Air Temperature': 55.979042,
#   'Wind Speed': 10.15146},
#  {'Timestamp': '2020-03-11T02:20:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5468496,
#   'Blade2 Actual': -0.63646126,
#   'Blade3 Actual': -0.5367961,
#   'Rotor Speed': 17.225594,
#   'State': 16,
#   'Active Power': 623.3333,
#   'Nacelle Position': 318.68866,
#   'Air Temperature': 55.99997,
#   'Wind Speed': 8.578952},
#  {'Timestamp': '2020-03-11T02:21:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5434128,
#   'Blade2 Actual': -0.6326009,
#   'Blade3 Actual': -0.5333009,
#   'Rotor Speed': 17.166092,
#   'State': 16,
#   'Active Power': 554.3077,
#   'Nacelle Position': 318.6952,
#   'Air Temperature': 56.020897,
#   'Wind Speed': 8.612205},
#  {'Timestamp': '2020-03-11T02:22:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.53997594,
#   'Blade2 Actual': -0.6287405,
#   'Blade3 Actual': -0.52980566,
#   'Rotor Speed': 16.647919,
#   'State': 16,
#   'Active Power': 535.5,
#   'Nacelle Position': 318.70175,
#   'Air Temperature': 56.04183,
#   'Wind Speed': 8.185802},
#  {'Timestamp': '2020-03-11T02:23:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.53653914,
#   'Blade2 Actual': -0.6248801,
#   'Blade3 Actual': -0.52631044,
#   'Rotor Speed': 16.072363,
#   'State': 16,
#   'Active Power': 521,
#   'Nacelle Position': 318.7083,
#   'Air Temperature': 56.062756,
#   'Wind Speed': 8.142385},
#  {'Timestamp': '2020-03-11T02:24:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.53310233,
#   'Blade2 Actual': -0.62101966,
#   'Blade3 Actual': -0.5228152,
#   'Rotor Speed': 17.20259,
#   'State': 16,
#   'Active Power': 557.55554,
#   'Nacelle Position': 318.71487,
#   'Air Temperature': 56.083683,
#   'Wind Speed': 7.977839},
#  {'Timestamp': '2020-03-11T02:25:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5296655,
#   'Blade2 Actual': -0.61715925,
#   'Blade3 Actual': -0.51932,
#   'Rotor Speed': 18.694801,
#   'State': 16,
#   'Active Power': 789.5455,
#   'Nacelle Position': 318.72144,
#   'Air Temperature': 56.10461,
#   'Wind Speed': 8.990828},
#  {'Timestamp': '2020-03-11T02:26:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5262287,
#   'Blade2 Actual': -0.6132989,
#   'Blade3 Actual': -0.5158248,
#   'Rotor Speed': 19.289911,
#   'State': 16,
#   'Active Power': 1010.5,
#   'Nacelle Position': 318.72803,
#   'Air Temperature': 56.12554,
#   'Wind Speed': 10.896481},
#  {'Timestamp': '2020-03-11T02:27:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.52279186,
#   'Blade2 Actual': -0.6094384,
#   'Blade3 Actual': -0.51232964,
#   'Rotor Speed': 19.581251,
#   'State': 16,
#   'Active Power': 879.94116,
#   'Nacelle Position': 318.73456,
#   'Air Temperature': 56.14647,
#   'Wind Speed': 9.693002},
#  {'Timestamp': '2020-03-11T02:28:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.51935506,
#   'Blade2 Actual': -0.60557806,
#   'Blade3 Actual': -0.5088344,
#   'Rotor Speed': 18.697477,
#   'State': 16,
#   'Active Power': 818.8571,
#   'Nacelle Position': 318.74112,
#   'Air Temperature': 56.167397,
#   'Wind Speed': 9.301006},
#  {'Timestamp': '2020-03-11T02:29:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.51591825,
#   'Blade2 Actual': -0.60171765,
#   'Blade3 Actual': -0.5053392,
#   'Rotor Speed': 18.517658,
#   'State': 16,
#   'Active Power': 761.6667,
#   'Nacelle Position': 318.74768,
#   'Air Temperature': 56.188328,
#   'Wind Speed': 9.653849},
#  {'Timestamp': '2020-03-11T02:30:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.51248145,
#   'Blade2 Actual': -0.59785724,
#   'Blade3 Actual': -0.501844,
#   'Rotor Speed': 17.80893,
#   'State': 16,
#   'Active Power': 702.4286,
#   'Nacelle Position': 318.75424,
#   'Air Temperature': 56.209255,
#   'Wind Speed': 9.014561},
#  {'Timestamp': '2020-03-11T02:31:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.50904465,
#   'Blade2 Actual': -0.5939968,
#   'Blade3 Actual': -0.49834877,
#   'Rotor Speed': 17.572803,
#   'State': 16,
#   'Active Power': 613.3667,
#   'Nacelle Position': 318.7608,
#   'Air Temperature': 56.230186,
#   'Wind Speed': 9.060244},
#  {'Timestamp': '2020-03-11T02:32:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': -0.5056078,
# ...
#   'Wind Speed': 0.40441027},
#  {'Timestamp': '2020-03-11T15:49:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.59992,
#   'Blade2 Actual': 82.582634,
#   'Blade3 Actual': 82.56806,
#   'Rotor Speed': 0.400392,
#   'State': 11,
#   'Active Power': -4.4138584,
#   'Nacelle Position': 325.63068,
#   'Air Temperature': 58.610466,
#   'Wind Speed': 0.9145088},
#  {'Timestamp': '2020-03-11T15:50:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.591965,
#   'Blade2 Actual': 82.57456,
#   'Blade3 Actual': 82.55976,
#   'Rotor Speed': 0.40017602,
#   'State': 11,
#   'Active Power': -4.4078937,
#   'Nacelle Position': 325.58,
#   'Air Temperature': 58.598785,
#   'Wind Speed': 1.468064},
#  {'Timestamp': '2020-03-11T15:51:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.58401,
#   'Blade2 Actual': 82.56649,
#   'Blade3 Actual': 82.55147,
#   'Rotor Speed': 0.39996007,
#   'State': 11,
#   'Active Power': -4.4019284,
#   'Nacelle Position': 325.5293,
#   'Air Temperature': 58.587105,
#   'Wind Speed': 1.3879017},
#  {'Timestamp': '2020-03-11T15:52:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.57605,
#   'Blade2 Actual': 82.55842,
#   'Blade3 Actual': 82.54317,
#   'Rotor Speed': 0.3997441,
#   'State': 11,
#   'Active Power': -4.3959637,
#   'Nacelle Position': 325.47864,
#   'Air Temperature': 58.575424,
#   'Wind Speed': 1.373692},
#  {'Timestamp': '2020-03-11T15:53:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.56809,
#   'Blade2 Actual': 82.55035,
#   'Blade3 Actual': 82.53487,
#   'Rotor Speed': 0.39952815,
#   'State': 11,
#   'Active Power': -4.389999,
#   'Nacelle Position': 325.42795,
#   'Air Temperature': 58.563744,
#   'Wind Speed': 1.2785968},
#  {'Timestamp': '2020-03-11T15:54:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.560135,
#   'Blade2 Actual': 82.542274,
#   'Blade3 Actual': 82.526566,
#   'Rotor Speed': 0.39931217,
#   'State': 11,
#   'Active Power': -4.384034,
#   'Nacelle Position': 325.37726,
#   'Air Temperature': 58.552063,
#   'Wind Speed': 3.006567},
#  {'Timestamp': '2020-03-11T15:55:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.55218,
#   'Blade2 Actual': 82.5342,
#   'Blade3 Actual': 82.51827,
#   'Rotor Speed': 0.39909622,
#   'State': 11,
#   'Active Power': -4.3780694,
#   'Nacelle Position': 318.18082,
#   'Air Temperature': 58.540382,
#   'Wind Speed': 1.645903},
#  {'Timestamp': '2020-03-11T15:56:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.54422,
#   'Blade2 Actual': 82.52613,
#   'Blade3 Actual': 82.50997,
#   'Rotor Speed': 0.39888024,
#   'State': 11,
#   'Active Power': -4.3721046,
#   'Nacelle Position': 282.40128,
#   'Air Temperature': 58.5287,
#   'Wind Speed': 1.381101},
#  {'Timestamp': '2020-03-11T15:57:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.53626,
#   'Blade2 Actual': 82.51807,
#   'Blade3 Actual': 82.50167,
#   'Rotor Speed': 0.3986643,
#   'State': 11,
#   'Active Power': -4.36614,
#   'Nacelle Position': 260.65067,
#   'Air Temperature': 58.517017,
#   'Wind Speed': 2.0415757},
#  {'Timestamp': '2020-03-11T15:58:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.528305,
#   'Blade2 Actual': 82.509995,
#   'Blade3 Actual': 82.49338,
#   'Rotor Speed': 0.39844832,
#   'State': 11,
#   'Active Power': -4.360175,
#   'Nacelle Position': 259.94354,
#   'Air Temperature': 58.505337,
#   'Wind Speed': 2.7613842},
#  {'Timestamp': '2020-03-11T15:59:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.52035,
#   'Blade2 Actual': 82.50192,
#   'Blade3 Actual': 82.48508,
#   'Rotor Speed': 0.39823237,
#   'State': 11,
#   'Active Power': -4.3542104,
#   'Nacelle Position': 259.2364,
#   'Air Temperature': 58.493656,
#   'Wind Speed': 1.0876065},
#  {'Timestamp': '2020-03-11T16:00:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.51239,
#   'Blade2 Actual': 82.49385,
#   'Blade3 Actual': 82.476776,
#   'Rotor Speed': 0.3980164,
#   'State': 11,
#   'Active Power': -4.348245,
#   'Nacelle Position': 258.52924,
#   'Air Temperature': 58.481976,
#   'Wind Speed': 1.1218024},
#  {'Timestamp': '2020-03-11T16:01:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.50443,
#   'Blade2 Actual': 82.48578,
#   'Blade3 Actual': 82.468475,
#   'Rotor Speed': 0.39780045,
#   'State': 11,
#   'Active Power': -4.3422804,
#   'Nacelle Position': 257.82208,
#   'Air Temperature': 58.470295,
#   'Wind Speed': 1.3940912},
#  {'Timestamp': '2020-03-11T16:02:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.496475,
#   'Blade2 Actual': 82.47771,
#   'Blade3 Actual': 82.46018,
#   'Rotor Speed': 0.3975845,
#   'State': 11,
#   'Active Power': -4.3363156,
#   'Nacelle Position': 257.11496,
#   'Air Temperature': 58.458614,
#   'Wind Speed': 1.43277},
#  {'Timestamp': '2020-03-11T16:03:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.48852,
#   'Blade2 Actual': 82.469635,
#   'Blade3 Actual': 82.45188,
#   'Rotor Speed': 0.39736852,
#   'State': 11,
#   'Active Power': -4.330351,
#   'Nacelle Position': 256.4078,
#   'Air Temperature': 58.446934,
#   'Wind Speed': 1.610221},
#  {'Timestamp': '2020-03-11T16:04:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.48056,
#   'Blade2 Actual': 82.46156,
#   'Blade3 Actual': 82.44358,
#   'Rotor Speed': 0.39715257,
#   'State': 11,
#   'Active Power': -4.324386,
#   'Nacelle Position': 255.70065,
#   'Air Temperature': 58.435253,
#   'Wind Speed': 0.4434508},
#  {'Timestamp': '2020-03-11T16:05:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.4726,
#   'Blade2 Actual': 82.45349,
#   'Blade3 Actual': 82.43529,
#   'Rotor Speed': 0.3969366,
#   'State': 11,
#   'Active Power': -4.3184214,
#   'Nacelle Position': 254.99352,
#   'Air Temperature': 58.423573,
#   'Wind Speed': 1.895025},
#  {'Timestamp': '2020-03-11T16:06:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.464645,
#   'Blade2 Actual': 82.44542,
#   'Blade3 Actual': 82.42699,
#   'Rotor Speed': 0.39672065,
#   'State': 11,
#   'Active Power': -4.3124566,
#   'Nacelle Position': 254.28636,
#   'Air Temperature': 58.411892,
#   'Wind Speed': 1.5759127},
#  {'Timestamp': '2020-03-11T16:07:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.45669,
#   'Blade2 Actual': 82.43735,
#   'Blade3 Actual': 82.418686,
#   'Rotor Speed': 0.39650467,
#   'State': 11,
#   'Active Power': -4.306492,
#   'Nacelle Position': 253.57922,
#   'Air Temperature': 58.40021,
#   'Wind Speed': 2.318404},
#  {'Timestamp': '2020-03-11T16:08:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.44873,
#   'Blade2 Actual': 82.42928,
#   'Blade3 Actual': 82.41039,
#   'Rotor Speed': 0.39628872,
#   'State': 11,
#   'Active Power': -4.300527,
#   'Nacelle Position': 252.87207,
#   'Air Temperature': 58.388527,
#   'Wind Speed': 1.527129},
#  {'Timestamp': '2020-03-11T16:09:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.44077,
#   'Blade2 Actual': 82.42121,
#   'Blade3 Actual': 82.40209,
#   'Rotor Speed': 0.39607275,
#   'State': 11,
#   'Active Power': -4.294562,
#   'Nacelle Position': 252.16493,
#   'Air Temperature': 58.376846,
#   'Wind Speed': 3.179205},
#  {'Timestamp': '2020-03-11T16:10:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.432816,
#   'Blade2 Actual': 82.41314,
#   'Blade3 Actual': 82.39379,
#   'Rotor Speed': 0.3958568,
#   'State': 11,
#   'Active Power': -4.288597,
#   'Nacelle Position': 251.45778,
#   'Air Temperature': 58.365166,
#   'Wind Speed': 2.202569},
#  {'Timestamp': '2020-03-11T16:11:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.42486,
#   'Blade2 Actual': 82.40507,
#   'Blade3 Actual': 82.38549,
#   'Rotor Speed': 0.39564082,
#   'State': 11,
#   'Active Power': -4.2826324,
#   'Nacelle Position': 250.75064,
#   'Air Temperature': 58.353485,
#   'Wind Speed': 0.8234928},
#  {'Timestamp': '2020-03-11T16:12:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 82.4169,
#   'Blade2 Actual': 82.396996,
#   'Blade3 Actual': 82.3772,
#   'Rotor Speed': 0.39542487,
#   'State': 11,
#   'Active Power': -4.2766676,
#   'Nacelle Position': 250.04349,
#   'Air Temperature': 58.341805,
#   'Wind Speed': 3.8328776},
#  {'Timestamp': '2020-03-11T16:13:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.88799,
#   'Blade2 Actual': 64.858055,
#   'Blade3 Actual': 64.84805,
#   'Rotor Speed': 0.39520893,
#   'State': 12,
#   'Active Power': -4.270703,
#   'Nacelle Position': 239.94382,
#   'Air Temperature': 58.330124,
#   'Wind Speed': 3.406789},
#  {'Timestamp': '2020-03-11T16:14:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.847824,
#   'Blade2 Actual': 64.819145,
#   'Blade3 Actual': 64.80914,
#   'Rotor Speed': 0.39499295,
#   'State': 12,
#   'Active Power': -4.264738,
#   'Nacelle Position': 204.01472,
#   'Air Temperature': 58.318443,
#   'Wind Speed': 2.44424},
#  {'Timestamp': '2020-03-11T16:15:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.807655,
#   'Blade2 Actual': 64.78023,
#   'Blade3 Actual': 64.770226,
#   'Rotor Speed': 0.394777,
#   'State': 12,
#   'Active Power': -4.2587733,
#   'Nacelle Position': 202.01202,
#   'Air Temperature': 58.306763,
#   'Wind Speed': 2.687534},
#  {'Timestamp': '2020-03-11T16:16:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.76749,
#   'Blade2 Actual': 64.74132,
#   'Blade3 Actual': 64.731316,
#   'Rotor Speed': 0.39456102,
#   'State': 12,
#   'Active Power': -4.2528086,
#   'Nacelle Position': 207.62547,
#   'Air Temperature': 58.295082,
#   'Wind Speed': 2.5413256},
#  {'Timestamp': '2020-03-11T16:17:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.727325,
#   'Blade2 Actual': 64.70241,
#   'Blade3 Actual': 64.692406,
#   'Rotor Speed': 0.39434507,
#   'State': 12,
#   'Active Power': -4.246844,
#   'Nacelle Position': 213.23892,
#   'Air Temperature': 58.2834,
#   'Wind Speed': 3.642615},
#  {'Timestamp': '2020-03-11T16:18:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.68716,
#   'Blade2 Actual': 64.66349,
#   'Blade3 Actual': 64.653496,
#   'Rotor Speed': 0.3941291,
#   'State': 12,
#   'Active Power': -4.2408786,
#   'Nacelle Position': 226.9923,
#   'Air Temperature': 58.27172,
#   'Wind Speed': 2.9303026},
#  {'Timestamp': '2020-03-11T16:19:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.64699,
#   'Blade2 Actual': 64.62458,
#   'Blade3 Actual': 64.61458,
#   'Rotor Speed': 0.39391315,
#   'State': 12,
#   'Active Power': -4.234914,
#   'Nacelle Position': 224.04851,
#   'Air Temperature': 58.26004,
#   'Wind Speed': 3.294202},
#  {'Timestamp': '2020-03-11T16:20:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.60682,
#   'Blade2 Actual': 64.58567,
#   'Blade3 Actual': 64.57567,
#   'Rotor Speed': 0.39369717,
#   'State': 12,
#   'Active Power': -4.228949,
#   'Nacelle Position': 221.10474,
#   'Air Temperature': 58.248356,
#   'Wind Speed': 3.160011},
#  {'Timestamp': '2020-03-11T16:21:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.56665,
#   'Blade2 Actual': 64.54675,
#   'Blade3 Actual': 64.53676,
#   'Rotor Speed': 0.39348122,
#   'State': 12,
#   'Active Power': -4.2229843,
#   'Nacelle Position': 218.16095,
#   'Air Temperature': 58.236675,
#   'Wind Speed': 2.889909},
#  {'Timestamp': '2020-03-11T16:22:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.52648,
#   'Blade2 Actual': 64.50784,
#   'Blade3 Actual': 64.49785,
#   'Rotor Speed': 0.39326525,
#   'State': 12,
#   'Active Power': -4.2170196,
#   'Nacelle Position': 215.21718,
#   'Air Temperature': 58.224995,
#   'Wind Speed': 3.016175},
#  {'Timestamp': '2020-03-11T16:23:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.48632,
#   'Blade2 Actual': 64.46893,
#   'Blade3 Actual': 64.45893,
#   'Rotor Speed': 0.3930493,
#   'State': 12,
#   'Active Power': -4.211055,
#   'Nacelle Position': 218.08539,
#   'Air Temperature': 58.213314,
#   'Wind Speed': 2.330733},
#  {'Timestamp': '2020-03-11T16:24:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.44615,
#   'Blade2 Actual': 64.43002,
#   'Blade3 Actual': 64.42002,
#   'Rotor Speed': 0.39283335,
#   'State': 12,
#   'Active Power': -4.20509,
#   'Nacelle Position': 222.10226,
#   'Air Temperature': 58.201633,
#   'Wind Speed': 3.0262625},
#  {'Timestamp': '2020-03-11T16:25:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.40598,
#   'Blade2 Actual': 64.391106,
#   'Blade3 Actual': 64.38111,
#   'Rotor Speed': 0.39261737,
#   'State': 12,
#   'Active Power': -4.1991253,
#   'Nacelle Position': 218.2911,
#   'Air Temperature': 58.189953,
#   'Wind Speed': 2.9774506},
#  {'Timestamp': '2020-03-11T16:26:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.365814,
#   'Blade2 Actual': 64.352196,
#   'Blade3 Actual': 64.3422,
#   'Rotor Speed': 0.18114789,
#   'State': 12,
#   'Active Power': -4.1931605,
#   'Nacelle Position': 214.47995,
#   'Air Temperature': 58.178272,
#   'Wind Speed': 1.8598824},
#  {'Timestamp': '2020-03-11T16:27:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.325645,
#   'Blade2 Actual': 64.313286,
#   'Blade3 Actual': 64.30328,
#   'Rotor Speed': 0.7243553,
#   'State': 12,
#   'Active Power': -4.187196,
#   'Nacelle Position': 210.6688,
#   'Air Temperature': 58.16659,
#   'Wind Speed': 3.847239},
#  {'Timestamp': '2020-03-11T16:28:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 64.285484,
#   'Blade2 Actual': 64.27437,
#   'Blade3 Actual': 64.26437,
#   'Rotor Speed': 1.2675627,
#   'State': 12,
#   'Active Power': -4.1812305,
#   'Nacelle Position': 206.85764,
#   'Air Temperature': 58.15491,
#   'Wind Speed': 3.8444831},
#  {'Timestamp': '2020-03-11T16:29:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 52.444443,
#   'Blade2 Actual': 52.46222,
#   'Blade3 Actual': 52.44978,
#   'Rotor Speed': 1.8107702,
#   'State': 14,
#   'Active Power': -4.175266,
#   'Nacelle Position': 200.60712,
#   'Air Temperature': 58.14323,
#   'Wind Speed': 3.7733636},
#  {'Timestamp': '2020-03-11T16:30:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 14.038281,
#   'Blade2 Actual': 14.033906,
#   'Blade3 Actual': 14.03,
#   'Rotor Speed': 4.583228,
#   'State': 14,
#   'Active Power': -4.169301,
#   'Nacelle Position': 215.58357,
#   'Air Temperature': 58.13155,
#   'Wind Speed': 2.27969},
#  {'Timestamp': '2020-03-11T16:31:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 4.0467935,
#   'Blade2 Actual': 4.0124583,
#   'Blade3 Actual': 4.0220065,
#   'Rotor Speed': 8.863575,
#   'State': 14,
#   'Active Power': -4.1633363,
#   'Nacelle Position': 220.20102,
#   'Air Temperature': 58.119865,
#   'Wind Speed': 3.2354608},
#  {'Timestamp': '2020-03-11T16:32:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 4.2870836,
#   'Blade2 Actual': 4.2038608,
#   'Blade3 Actual': 4.232397,
#   'Rotor Speed': 11.464682,
#   'State': 15,
#   'Active Power': -4.1573715,
#   'Nacelle Position': 207.6381,
#   'Air Temperature': 58.108185,
#   'Wind Speed': 2.4186707},
#  {'Timestamp': '2020-03-11T16:33:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 4.527374,
#   'Blade2 Actual': 4.395263,
#   'Blade3 Actual': 4.442788,
#   'Rotor Speed': 11.85774,
#   'State': 15,
#   'Active Power': -4.151407,
#   'Nacelle Position': 214.71834,
#   'Air Temperature': 58.096504,
#   'Wind Speed': 2.345572},
#  {'Timestamp': '2020-03-11T16:34:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 4.767664,
#   'Blade2 Actual': 4.586666,
#   'Blade3 Actual': 4.653179,
#   'Rotor Speed': 13.868831,
#   'State': 15,
#   'Active Power': -4.145442,
#   'Nacelle Position': 215.46039,
#   'Air Temperature': 58.084824,
#   'Wind Speed': 2.619574},
#  {'Timestamp': '2020-03-11T16:35:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 5.0079536,
#   'Blade2 Actual': 4.7780685,
#   'Blade3 Actual': 4.8635697,
#   'Rotor Speed': 13.351339,
#   'State': 15,
#   'Active Power': -4.1394773,
#   'Nacelle Position': 211.169,
#   'Air Temperature': 58.073143,
#   'Wind Speed': 2.7546859},
#  {'Timestamp': '2020-03-11T16:36:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 5.248244,
#   'Blade2 Actual': 4.969471,
#   'Blade3 Actual': 5.073961,
#   'Rotor Speed': 12.833847,
#   'State': 15,
#   'Active Power': -4.1335125,
#   'Nacelle Position': 206.87762,
#   'Air Temperature': 58.061462,
#   'Wind Speed': 1.977203},
#  {'Timestamp': '2020-03-11T16:37:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 5.488534,
#   'Blade2 Actual': 5.160874,
#   'Blade3 Actual': 5.284352,
#   'Rotor Speed': 12.316356,
#   'State': 15,
#   'Active Power': -4.1275473,
#   'Nacelle Position': 202.58623,
#   'Air Temperature': 58.04978,
#   'Wind Speed': 1.912093},
#  {'Timestamp': '2020-03-11T16:38:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 5.7288237,
#   'Blade2 Actual': 5.3522763,
#   'Blade3 Actual': 5.4947424,
#   'Rotor Speed': 11.739981,
#   'State': 15,
#   'Active Power': -4.1215825,
#   'Nacelle Position': 198.28542,
#   'Air Temperature': 58.0381,
#   'Wind Speed': 2.609523},
#  {'Timestamp': '2020-03-11T16:39:00Z',
#   'Turbine': 'GE01',
#   'Blade1 Actual': 5.969114,
#   'Blade2 Actual': 5.543679,
#   'Blade3 Actual': 5.7051334,
#   'Rotor Speed': 10.830197,
#   'State': 15,
#   'Active Power': -4.1156178,
#   'Nacelle Position': 220.24681,
#   'Air Temperature': 58.02642,
#   'Wind Speed': 3.20783},
#  ...]

# %%
df = pd.DataFrame(data)
df["Timestamp"] = pd.to_datetime(df["Timestamp"])
df
# Out:
#        Active Power  Air Temperature  Blade1 Actual  Blade2 Actual  \
# 0         393.81445        57.547790      -0.543748      -0.508561
# 1         405.43518        57.531895      -0.541356      -0.506288
# 2         307.92307        57.516000      -0.538963      -0.504015
# 3         618.70000        57.500107      -0.536571      -0.501742
# 4         641.00000        57.484210      -0.534179      -0.499470
# 5         369.75000        57.468315      -0.531786      -0.497197
# 6         478.80000        57.452420      -0.529394      -0.494924
# 7         657.55000        57.436523      -0.527002      -0.492652
# 8         871.66670        57.420628      -0.524609      -0.490379
# 9         563.49230        57.404730      -0.522217      -0.488106
# 10        616.41670        57.388836      -0.519825      -0.485833
# 11        358.69983        57.372940      -0.517432      -0.483561
# 12        420.00000        57.357044      -0.515040      -0.481288
# 13        465.33334        57.341150      -0.512648      -0.479015
# 14        465.40000        57.325253      -0.510255      -0.476742
# 15        668.12500        57.309357      -0.507863      -0.474470
# 16        836.00000        57.293460      -0.505471      -0.472197
# 17       1025.00000        57.277565      -0.503078      -0.469924
# 18       1048.00000        57.261670      -0.500686      -0.467652
# 19       1150.00000        57.245773      -0.498293      -0.465379
# 20        806.07404        57.229877      -0.495901      -0.463106
# 21       1014.00000        57.213980      -0.493509      -0.460833
# 22        840.00000        57.198090      -0.491116      -0.458561
# 23        965.00000        57.182194      -0.488724      -0.456288
# 24        878.50000        57.166298      -0.486332      -0.454015
# 25       1105.00000        57.150402      -0.483939      -0.451742
# 26        631.00000        57.134506      -0.481547      -0.449470
# 27        779.00000        57.118610      -0.479155      -0.447197
# 28        554.76950        57.102715      -0.476762      -0.444924
# 29        425.90910        57.086820      -0.474370      -0.442651
# ...             ...              ...            ...            ...
# 14380     230.60000        64.798294       0.042912      -0.035805
# 14381     319.66666        64.833910       0.050528      -0.027589
# 14382     470.19376        64.869514       0.058143      -0.019372
# 14383     441.43527        64.905120       0.065758      -0.011156
# 14384     429.05606        64.940730       0.073373      -0.002939
# 14385     383.63460        64.976330       0.080989       0.005277
# 14386     497.90180        65.011940       0.088604       0.013494
# 14387     559.33330        65.047550       0.096219       0.021710
# 14388     790.00000        65.083150       0.103834       0.029927
# 14389     734.68420        65.118770       0.111450       0.038143
# 14390     540.43176        65.154370       0.119065       0.046359
# 14391     388.91257        65.189980       0.126680       0.054576
# 14392     277.72296        65.225586       0.134295       0.062792
# 14393     177.63637        65.261190       0.141910       0.071009
# 14394     232.25757        65.296800       0.149526       0.079225
# 14395     342.40480        65.332405       0.157141       0.087442
# 14396     714.10000        65.368020       0.164756       0.095658
# 14397     440.00000        65.403625       0.172371       0.103874
# 14398     479.00000        65.439230       0.179987       0.112091
# 14399     650.16330        65.474840       0.187602       0.120307
# 14400     510.58444        65.510445       0.195217       0.128524
# 14401     890.44104        65.546050       0.202832       0.136740
# 14402     661.58330        65.581660       0.210448       0.144957
# 14403     356.71667        65.617260       0.218063       0.153173
# 14404     466.20000        65.652880       0.225678       0.161389
# 14405     401.50000        65.688484       0.233293       0.169606
# 14406     448.58334        65.724090       0.240908       0.177822
# 14407     276.98816        65.759700       0.248524       0.186039
# 14408     222.51347        65.795300       0.256139       0.194255
# 14409     165.35239        65.830910       0.263754       0.202472
#
#        Blade3 Actual  Nacelle Position  Rotor Speed  State  \
# 0          -0.111478         304.80900    15.482932     16
# 1          -0.098839         304.64220    14.812955     16
# 2          -0.086199         304.47540    13.750278     16
# 3          -0.073560         304.30860    17.696032     16
# 4          -0.060921         304.21494    17.967062     16
# 5          -0.048281         304.29200    14.665382     16
# 6          -0.035642         304.36905    16.251783     16
# 7          -0.023003         304.44608    17.437292     16
# 8          -0.010363         304.52313    19.132862     16
# 9           0.002276         304.60020    17.187315     16
# 10          0.014915         304.67725    17.507158     16
# 11          0.027554         304.75427    15.039915     16
# 12          0.040194         304.83133    15.584111     16
# 13          0.052833         304.90840    15.537004     16
# 14          0.065472         304.98540    15.217642     16
# 15          0.078112         305.06247    18.417603     16
# 16          0.090751         305.13953    18.883170     16
# 17          0.103390         305.21655    19.937363     16
# 18          0.105344         305.29360    19.595356     16
# 19          0.084240         305.29858    19.281563     16
# 20          0.063136         305.25210    18.698137     16
# 21          0.042032         305.20560    19.523144     16
# 22          0.020927         305.15912    19.937809     16
# 23         -0.000177         305.11264    19.423122     16
# 24         -0.021281         305.06613    19.183752     16
# 25         -0.042385         305.01965    19.680449     16
# 26         -0.063490         304.97314    18.108139     16
# 27         -0.084594         304.92667    18.230087     16
# 28         -0.105698         304.88016    16.403402     16
# 29         -0.126802         304.83368    15.516993     16
# ...              ...               ...          ...    ...
# 14380       0.067898         227.46834    13.016433     16
# 14381       0.075246         227.49800    14.693632     16
# 14382       0.082594         227.52766    16.491330     16
# 14383       0.089942         227.55733    16.001621     16
# 14384       0.097290         227.58699    15.342868     16
# 14385       0.104638         227.61667    15.073609     16
# 14386       0.111986         227.64633    16.322525     16
# 14387       0.119334         227.67600    16.643253     16
# 14388       0.126682         227.70566    19.326315     16
# 14389       0.134030         227.73532    18.667976     16
# 14390       0.141378         227.76500    16.909365     16
# 14391       0.148726         227.79466    15.150755     16
# 14392       0.156074         227.82433    13.357500     16
# 14393       0.163422         227.85399    12.313415     16
# 14394       0.170770         227.88365    12.680224     16
# 14395       0.178118         227.91331    14.119565     16
# 14396       0.185466         227.94300    18.260193     16
# 14397       0.192814         227.97266    15.397083     16
# 14398       0.200163         228.00232    16.756380     16
# 14399       0.207511         228.03198    17.658155     16
# 14400       0.214859         228.06165    16.460588     16
# 14401       0.222207         228.09132    19.490532     16
# 14402       0.229555         228.12099    17.677198     16
# 14403       0.236903         228.15065    14.860024     16
# 14404       0.244251         228.18031    15.575707     16
# 14405       0.251599         228.20998    15.938308     16
# 14406       0.258947         228.23964    15.429196     16
# 14407       0.266295         228.26932    13.958876     16
# 14408       0.273643         228.29898    12.944016     16
# 14409       0.280991         228.32864    12.648631     16
#
#                 Timestamp Turbine  Wind Speed
# 0     2020-03-11 00:00:00    GE01    6.947662
# 1     2020-03-11 00:01:00    GE01    6.636685
# 2     2020-03-11 00:02:00    GE01    6.979335
# 3     2020-03-11 00:03:00    GE01    7.525977
# 4     2020-03-11 00:04:00    GE01    8.931692
# 5     2020-03-11 00:05:00    GE01    7.206466
# 6     2020-03-11 00:06:00    GE01    6.801806
# 7     2020-03-11 00:07:00    GE01    8.190707
# 8     2020-03-11 00:08:00    GE01    9.397439
# 9     2020-03-11 00:09:00    GE01    7.469274
# 10    2020-03-11 00:10:00    GE01    8.385828
# 11    2020-03-11 00:11:00    GE01    7.107357
# 12    2020-03-11 00:12:00    GE01    7.418766
# 13    2020-03-11 00:13:00    GE01    9.056112
# 14    2020-03-11 00:14:00    GE01    7.914674
# 15    2020-03-11 00:15:00    GE01    9.064996
# 16    2020-03-11 00:16:00    GE01    9.354413
# 17    2020-03-11 00:17:00    GE01   10.392280
# 18    2020-03-11 00:18:00    GE01   10.257415
# 19    2020-03-11 00:19:00    GE01   10.664617
# 20    2020-03-11 00:20:00    GE01    9.055866
# 21    2020-03-11 00:21:00    GE01   10.535706
# 22    2020-03-11 00:22:00    GE01    8.929344
# 23    2020-03-11 00:23:00    GE01   10.832280
# 24    2020-03-11 00:24:00    GE01    9.724257
# 25    2020-03-11 00:25:00    GE01   10.495991
# 26    2020-03-11 00:26:00    GE01    8.704097
# 27    2020-03-11 00:27:00    GE01    9.639395
# 28    2020-03-11 00:28:00    GE01    7.591608
# 29    2020-03-11 00:29:00    GE01    8.137148
# ...                   ...     ...         ...
# 14380 2020-03-11 23:31:00    GE10    6.463467
# 14381 2020-03-11 23:32:00    GE10    6.191443
# 14382 2020-03-11 23:33:00    GE10    7.819974
# 14383 2020-03-11 23:34:00    GE10    6.972343
# 14384 2020-03-11 23:35:00    GE10    7.221636
# 14385 2020-03-11 23:36:00    GE10    7.053028
# 14386 2020-03-11 23:37:00    GE10    8.528529
# 14387 2020-03-11 23:38:00    GE10    8.557046
# 14388 2020-03-11 23:39:00    GE10    9.119464
# 14389 2020-03-11 23:40:00    GE10    9.326195
# 14390 2020-03-11 23:41:00    GE10    7.957028
# 14391 2020-03-11 23:42:00    GE10    7.428816
# 14392 2020-03-11 23:43:00    GE10    6.426625
# 14393 2020-03-11 23:44:00    GE10    5.917082
# 14394 2020-03-11 23:45:00    GE10    7.106111
# 14395 2020-03-11 23:46:00    GE10    7.922050
# 14396 2020-03-11 23:47:00    GE10    7.939672
# 14397 2020-03-11 23:48:00    GE10    7.827018
# 14398 2020-03-11 23:49:00    GE10    7.083036
# 14399 2020-03-11 23:50:00    GE10    7.992529
# 14400 2020-03-11 23:51:00    GE10    8.297863
# 14401 2020-03-11 23:52:00    GE10    9.288495
# 14402 2020-03-11 23:53:00    GE10    8.890258
# 14403 2020-03-11 23:54:00    GE10    7.388952
# 14404 2020-03-11 23:55:00    GE10    7.301520
# 14405 2020-03-11 23:56:00    GE10    7.456245
# 14406 2020-03-11 23:57:00    GE10    8.050763
# 14407 2020-03-11 23:58:00    GE10    6.243790
# 14408 2020-03-11 23:59:00    GE10    6.711619
# 14409 2020-03-12 00:00:00    GE10    6.228783
#
# [14410 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Renaming DataFrame column names to abbreviations, in order to display these column names clearly in a correlation plot 

df.rename(columns = {'Blade1 Actual':'BL1', 'Blade2 Actual':'BL2', 
                     'Blade3 Actual':'BL3', 'Rotor Speed':'RS','Turbine':'TS', 
                     'Active Power':'AP', 'Nacelle Position':'NP', 'Air Temperature':'AT',
                     'Wind Speed':'WS'}, inplace = True)

# %%
#Check the correlation between Active Power and the rest of the variables

#retrieve the correlation table
df_corr = df.corr()

#increase the size of the figure
fig = plt.figure(figsize=(50,10))
ax = fig.add_subplot(111)

#set the color pallete (Red, yellow, green)
cax = ax.matshow(df_corr, cmap=plt.cm.RdYlGn)
fig.colorbar(cax)

#configure the labels
labels = [c for c in df_corr.columns]

#make sure to show all the labels
ax.set_xticks(np.arange(len(labels)))
ax.set_yticks(np.arange(len(labels)))

#Setting labels for the x and y axes of the correlation plot
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)

plt.show()

# %%
#Renaming DataFrame column names from abbreviations back to their original full names

df.rename(columns = {'BL1':'Blade1', 'BL2':'Blade2', 
                     'BL3':'Blade3', 'RS':'Rotor Speed Value','TS':'Turbine', 
                     'AP':'Active Power Value','NP':'Nacelle Position Value', 'AT':'Air Temperature Value',
                     'WS':'Wind Speed Value'}, inplace = True)

# %%
#Plotting Active Power versus Wind Speed

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.scatter(df['Wind Speed Value'], df['Active Power Value'])
ax.set_xlabel('Wind Speed (m/s)')
ax.set_ylabel('Active Power (kW)')
ax.set_title('Active Power vs Wind Speed')

plt.show()

# %%
# df = df.dropna()

# %%
# df = df.dropna() #not needed
#Remove the GE05 turbine rows from the data frame because it has a lower rating relative to all the other turbines
filterOutGE05 = df['Turbine'] != "GE05"
df_Filter = df[filterOutGE05]

# %%
#Filter out negative & excessive Active Power Values
filterNegativeActivePower = (df_Filter['Active Power Value'] >= 0) 
df_Filter = df_Filter[filterNegativeActivePower]

# %%
#Remove the rows where we have a high wind speed and low active power in order to keep only the normal operating conditions
filterOutLowPowerHighWindSpeedData = (~((df_Filter['Wind Speed Value'] >  10) & (df_Filter['Active Power Value'] <600)))
df_Filter = df_Filter[filterOutLowPowerHighWindSpeedData]

# %%
#Keep only the rows which correspond to the "Load Operation" state
filterLoadOperationState = df_Filter['State'] == 16
df_Filter = df_Filter[filterLoadOperationState]

# %%
#Filter out high Wind Speeds (> 13 m/s) that do not change the Active Power results
filterOutHighWind = df_Filter['Wind Speed Value'] <13
df_Filter = df_Filter[filterOutHighWind]

# %%
#Plotting Active Power versus Wind Speed - filtered data frame representing Normal Operating Conditions

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.scatter(df_Filter['Wind Speed Value'], df_Filter['Active Power Value'])
ax.set_xlabel('Wind Speed (m/s)')
ax.set_ylabel('Active Power (kW)')
ax.set_title('Active Power vs Wind Speed')

plt.show()

# %%
#Prepare the training & testing/scoring data sets, and split them randomly
from sklearn.model_selection import train_test_split
#define the target variable to be predicted
y = df_Filter['Active Power Value'].values
#split the dataset randomly into test and train sets
X_train, X_test, y_train, y_test = train_test_split(df_Filter[['Air Temperature Value', 'Wind Speed Value']].values, 
                                                    y, test_size=0.25, random_state=42)

# %%
#Use the Decision Tree Regression Machine Learning model from scikit-learn
from sklearn.tree import DecisionTreeRegressor
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)

# Predict
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# %%
# Plot the results
plt.figure(figsize=(10,10))
plt.scatter(X_train[:,1], y_train, s=20, edgecolor="black", c="darkorange", label="data")
plt.plot(X_test[:,1], y_1, color="cornflowerblue",label="max_depth=2", linewidth=2)
plt.plot(X_test[:,1], y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("Wind Speed")
plt.ylabel("Active Power")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()

# %%
#save the machine learning model to disk
import pickle
filename = 'WT_ActivePower_model.sav'
pickle.dump(regr_2, open(filename, 'wb'))

# %%
#Test the model with the scoring/testing data set
loaded_model = pickle.load(open(filename, 'rb'))
global result
result = loaded_model.score(X_test, y_test)
#print the model score
print(result)
# Out:
# 0.9087426525813225

# %%
#Sample prediction
# define input
new_input = [[45, 6.6]] #Temp=45 F, Wind Speed = 6.6 m/s
# get prediction for new input
new_output = regr_2.predict(new_input)
print(new_output)
# Out:
# [348.57358041]

# %%
#Call the OpenWeather API to retrieve the forecasted air temperature and wind speed for Amarillo, TX for the next 5 days
import requests
url="https://api.openweathermap.org/data/2.5/forecast?q=Amarillo,US&APPID=5dac981ce33f41f61d8d1ea06ee89798"
responseWeatherForecast=requests.get(url)

# %%
responseWeatherForecast.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1594317600,
#    'main': {'temp': 312.27,
#     'feels_like': 307.14,
#     'temp_min': 312.27,
#     'temp_max': 312.64,
#     'pressure': 1009,
#     'sea_level': 1006,
#     'grnd_level': 892,
#     'humidity': 13,
#     'temp_kf': -0.37},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 5.91, 'deg': 293},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-09 18:00:00'},
#   {'dt': 1594328400,
#    'main': {'temp': 313.45,
#     'feels_like': 306.63,
#     'temp_min': 313.45,
#     'temp_max': 313.88,
#     'pressure': 1005,
#     'sea_level': 1003,
#     'grnd_level': 890,
#     'humidity': 9,
#     'temp_kf': -0.43},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 7.19, 'deg': 296},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-09 21:00:00'},
#   {'dt': 1594339200,
#    'main': {'temp': 312.28,
#     'feels_like': 307.05,
#     'temp_min': 312.28,
#     'temp_max': 312.31,
#     'pressure': 1004,
#     'sea_level': 1003,
#     'grnd_level': 889,
#     'humidity': 8,
#     'temp_kf': -0.03},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.4, 'deg': 336},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-10 00:00:00'},
#   {'dt': 1594350000,
#    'main': {'temp': 303.95,
#     'feels_like': 301.08,
#     'temp_min': 303.89,
#     'temp_max': 303.95,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 888,
#     'humidity': 15,
#     'temp_kf': 0.06},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.52, 'deg': 66},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-10 03:00:00'},
#   {'dt': 1594360800,
#    'main': {'temp': 302.44,
#     'feels_like': 296.89,
#     'temp_min': 302.44,
#     'temp_max': 302.44,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 889,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 7.96, 'deg': 205},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-10 06:00:00'},
#   {'dt': 1594371600,
#    'main': {'temp': 301.14,
#     'feels_like': 296.96,
#     'temp_min': 301.14,
#     'temp_max': 301.14,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 890,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 7.53, 'deg': 213},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-10 09:00:00'},
#   {'dt': 1594382400,
#    'main': {'temp': 298.77,
#     'feels_like': 296.5,
#     'temp_min': 298.77,
#     'temp_max': 298.77,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 891,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.63, 'deg': 242},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-10 12:00:00'},
#   {'dt': 1594393200,
#    'main': {'temp': 300.24,
#     'feels_like': 298.5,
#     'temp_min': 300.24,
#     'temp_max': 300.24,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 893,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 6.04, 'deg': 351},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-10 15:00:00'},
#   {'dt': 1594404000,
#    'main': {'temp': 306.08,
#     'feels_like': 305.08,
#     'temp_min': 306.08,
#     'temp_max': 306.08,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 895,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.72, 'deg': 337},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-10 18:00:00'},
#   {'dt': 1594414800,
#    'main': {'temp': 310.66,
#     'feels_like': 309.35,
#     'temp_min': 310.66,
#     'temp_max': 310.66,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 894,
#     'humidity': 20,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.22, 'deg': 311},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-10 21:00:00'},
#   {'dt': 1594425600,
#    'main': {'temp': 311.6,
#     'feels_like': 309.62,
#     'temp_min': 311.6,
#     'temp_max': 311.6,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 894,
#     'humidity': 16,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.21, 'deg': 303},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-11 00:00:00'},
#   {'dt': 1594436400,
#    'main': {'temp': 304.9,
#     'feels_like': 302.94,
#     'temp_min': 304.9,
#     'temp_max': 304.9,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 893,
#     'humidity': 24,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 2.37, 'deg': 341},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-11 03:00:00'},
#   {'dt': 1594447200,
#    'main': {'temp': 303.49,
#     'feels_like': 300.03,
#     'temp_min': 303.49,
#     'temp_max': 303.49,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 893,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 4.72, 'deg': 198},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-11 06:00:00'},
#   {'dt': 1594458000,
#    'main': {'temp': 301.51,
#     'feels_like': 296.86,
#     'temp_min': 301.51,
#     'temp_max': 301.51,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 893,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 7.46, 'deg': 223},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-11 09:00:00'},
#   {'dt': 1594468800,
#    'main': {'temp': 300.04,
#     'feels_like': 297.01,
#     'temp_min': 300.04,
#     'temp_max': 300.04,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 893,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 5.94, 'deg': 238},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-11 12:00:00'},
#   {'dt': 1594479600,
#    'main': {'temp': 305.88,
#     'feels_like': 302.92,
#     'temp_min': 305.88,
#     'temp_max': 305.88,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 895,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.96, 'deg': 253},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-11 15:00:00'},
#   {'dt': 1594490400,
#    'main': {'temp': 311.88,
#     'feels_like': 309.27,
#     'temp_min': 311.88,
#     'temp_max': 311.88,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 897,
#     'humidity': 18,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.84, 'deg': 263},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-11 18:00:00'},
#   {'dt': 1594501200,
#    'main': {'temp': 313.11,
#     'feels_like': 311.11,
#     'temp_min': 313.11,
#     'temp_max': 313.11,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 895,
#     'humidity': 13,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 29},
#    'wind': {'speed': 1.63, 'deg': 352},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-11 21:00:00'},
#   {'dt': 1594512000,
#    'main': {'temp': 312.01,
#     'feels_like': 310.5,
#     'temp_min': 312.01,
#     'temp_max': 312.01,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 893,
#     'humidity': 14,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 57},
#    'wind': {'speed': 1, 'deg': 198},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-12 00:00:00'},
#   {'dt': 1594522800,
#    'main': {'temp': 305.54,
#     'feels_like': 302.09,
#     'temp_min': 305.54,
#     'temp_max': 305.54,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 893,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 5.15, 'deg': 36},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-12 03:00:00'},
#   {'dt': 1594533600,
#    'main': {'temp': 300.51,
#     'feels_like': 298.14,
#     'temp_min': 300.51,
#     'temp_max': 300.51,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 893,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 4.52, 'deg': 98},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-12 06:00:00'},
#   {'dt': 1594544400,
#    'main': {'temp': 299.15,
#     'feels_like': 296.87,
#     'temp_min': 299.15,
#     'temp_max': 299.15,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 893,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 3.55, 'deg': 137},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-12 09:00:00'},
#   {'dt': 1594555200,
#    'main': {'temp': 297.15,
#     'feels_like': 294.93,
#     'temp_min': 297.15,
#     'temp_max': 297.15,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 893,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 54},
#    'wind': {'speed': 4.47, 'deg': 154},
#    'rain': {'3h': 0.21},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-12 12:00:00'},
#   {'dt': 1594566000,
#    'main': {'temp': 303.85,
#     'feels_like': 300.46,
#     'temp_min': 303.85,
#     'temp_max': 303.85,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 895,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 5.36, 'deg': 191},
#    'rain': {'3h': 0.28},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-12 15:00:00'},
#   {'dt': 1594576800,
#    'main': {'temp': 312.47,
#     'feels_like': 305.47,
#     'temp_min': 312.47,
#     'temp_max': 312.47,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 896,
#     'humidity': 13,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 8.63, 'deg': 228},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-12 18:00:00'},
#   {'dt': 1594587600,
#    'main': {'temp': 315.18,
#     'feels_like': 309.49,
#     'temp_min': 315.18,
#     'temp_max': 315.18,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 892,
#     'humidity': 11,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 6.66, 'deg': 246},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-12 21:00:00'},
#   {'dt': 1594598400,
#    'main': {'temp': 311.45,
#     'feels_like': 309.42,
#     'temp_min': 311.45,
#     'temp_max': 311.45,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 891,
#     'humidity': 15,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 48},
#    'wind': {'speed': 1.93, 'deg': 263},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-13 00:00:00'},
#   {'dt': 1594609200,
#    'main': {'temp': 303.04,
#     'feels_like': 299.48,
#     'temp_min': 303.04,
#     'temp_max': 303.04,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 891,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.31, 'deg': 211},
#    'rain': {'3h': 1.03},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-13 03:00:00'},
#   {'dt': 1594620000,
#    'main': {'temp': 300.54,
#     'feels_like': 299.48,
#     'temp_min': 300.54,
#     'temp_max': 300.54,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 891,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.14, 'deg': 195},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-13 06:00:00'},
#   {'dt': 1594630800,
#    'main': {'temp': 299.59,
#     'feels_like': 296.98,
#     'temp_min': 299.59,
#     'temp_max': 299.59,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 889,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.85, 'deg': 211},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-13 09:00:00'},
#   {'dt': 1594641600,
#    'main': {'temp': 299.51,
#     'feels_like': 294.69,
#     'temp_min': 299.51,
#     'temp_max': 299.51,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 889,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.01, 'deg': 229},
#    'rain': {'3h': 0.15},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-13 12:00:00'},
#   {'dt': 1594652400,
#    'main': {'temp': 305.64,
#     'feels_like': 298.69,
#     'temp_min': 305.64,
#     'temp_max': 305.64,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 891,
#     'humidity': 18,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 8.35, 'deg': 225},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-13 15:00:00'},
#   {'dt': 1594663200,
#    'main': {'temp': 311.88,
#     'feels_like': 305.68,
#     'temp_min': 311.88,
#     'temp_max': 311.88,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 891,
#     'humidity': 14,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 7.67, 'deg': 223},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-13 18:00:00'},
#   {'dt': 1594674000,
#    'main': {'temp': 315.3,
#     'feels_like': 310.11,
#     'temp_min': 315.3,
#     'temp_max': 315.3,
#     'pressure': 1002,
#     'sea_level': 1002,
#     'grnd_level': 889,
#     'humidity': 10,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 19},
#    'wind': {'speed': 5.58, 'deg': 238},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-13 21:00:00'},
#   {'dt': 1594684800,
#    'main': {'temp': 313.47,
#     'feels_like': 307.42,
#     'temp_min': 313.47,
#     'temp_max': 313.47,
#     'pressure': 1001,
#     'sea_level': 1001,
#     'grnd_level': 888,
#     'humidity': 12,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 44},
#    'wind': {'speed': 7.16, 'deg': 223},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-14 00:00:00'},
#   {'dt': 1594695600,
#    'main': {'temp': 305,
#     'feels_like': 300.1,
#     'temp_min': 305,
#     'temp_max': 305,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 888,
#     'humidity': 24,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 6.6, 'deg': 212},
#    'rain': {'3h': 0.87},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-14 03:00:00'},
#   {'dt': 1594706400,
#    'main': {'temp': 303.23,
#     'feels_like': 296.66,
#     'temp_min': 303.23,
#     'temp_max': 303.23,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 888,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 9.08, 'deg': 197},
#    'rain': {'3h': 0.65},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-14 06:00:00'},
#   {'dt': 1594717200,
#    'main': {'temp': 302.01,
#     'feels_like': 292.67,
#     'temp_min': 302.01,
#     'temp_max': 302.01,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 887,
#     'humidity': 22,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 42},
#    'wind': {'speed': 11.74, 'deg': 216},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-14 09:00:00'},
#   {'dt': 1594728000,
#    'main': {'temp': 300.91,
#     'feels_like': 293.14,
#     'temp_min': 300.91,
#     'temp_max': 300.91,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 887,
#     'humidity': 22,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 36},
#    'wind': {'speed': 9.24, 'deg': 226},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-14 12:00:00'},
#   {'dt': 1594738800,
#    'main': {'temp': 305.82,
#     'feels_like': 299.23,
#     'temp_min': 305.82,
#     'temp_max': 305.82,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 889,
#     'humidity': 19,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 8.1, 'deg': 233},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-14 15:00:00'}],
#  'city': {'id': 5516233,
#   'name': 'Amarillo',
#   'coord': {'lat': 35.222, 'lon': -101.8313},
#   'country': 'US',
#   'population': 190695,
#   'timezone': -18000,
#   'sunrise': 1594294837,
#   'sunset': 1594346654}}

# %%
#Store the forecasted air temperature, wind speed and timestamp from the API json response in a pandas DataFrame

from decimal import Decimal
import datetime
TempArray = []
WindSpeedArray = []
TimestampArray = []

for val in responseWeatherForecast.json()["list"]:
    tempKelvin = val["main"]["temp"]
    tempF = round(((tempKelvin - 273.15) * (9/5)) + 32, 2)
    windSpeedMeterPerSec = round(val["wind"]["speed"], 2)
    np.array(TempArray.append(tempF))
    np.array(WindSpeedArray.append(windSpeedMeterPerSec))
    np.array(TimestampArray.append(datetime.datetime.strptime(val["dt_txt"], '%Y-%m-%d %H:%M:%S')))   
          
dfWeatherForecast = pd.DataFrame({'Timestamp':TimestampArray, 'Temp (F)':TempArray, 'Wind Speed (m/s)':WindSpeedArray})        
                              
dfWeatherForecast
# Out:
#              Timestamp  Temp (F)  Wind Speed (m/s)
# 0  2020-07-09 18:00:00    102.42              5.91
# 1  2020-07-09 21:00:00    104.54              7.19
# 2  2020-07-10 00:00:00    102.43              4.40
# 3  2020-07-10 03:00:00     87.44              1.52
# 4  2020-07-10 06:00:00     84.72              7.96
# 5  2020-07-10 09:00:00     82.38              7.53
# 6  2020-07-10 12:00:00     78.12              4.63
# 7  2020-07-10 15:00:00     80.76              6.04
# 8  2020-07-10 18:00:00     91.27              3.72
# 9  2020-07-10 21:00:00     99.52              2.22
# 10 2020-07-11 00:00:00    101.21              2.21
# 11 2020-07-11 03:00:00     89.15              2.37
# 12 2020-07-11 06:00:00     86.61              4.72
# 13 2020-07-11 09:00:00     83.05              7.46
# 14 2020-07-11 12:00:00     80.40              5.94
# 15 2020-07-11 15:00:00     90.91              5.96
# 16 2020-07-11 18:00:00    101.71              3.84
# 17 2020-07-11 21:00:00    103.93              1.63
# 18 2020-07-12 00:00:00    101.95              1.00
# 19 2020-07-12 03:00:00     90.30              5.15
# 20 2020-07-12 06:00:00     81.25              4.52
# 21 2020-07-12 09:00:00     78.80              3.55
# 22 2020-07-12 12:00:00     75.20              4.47
# 23 2020-07-12 15:00:00     87.26              5.36
# 24 2020-07-12 18:00:00    102.78              8.63
# 25 2020-07-12 21:00:00    107.65              6.66
# 26 2020-07-13 00:00:00    100.94              1.93
# 27 2020-07-13 03:00:00     85.80              5.31
# 28 2020-07-13 06:00:00     81.30              2.14
# 29 2020-07-13 09:00:00     79.59              3.85
# 30 2020-07-13 12:00:00     79.45              6.01
# 31 2020-07-13 15:00:00     90.48              8.35
# 32 2020-07-13 18:00:00    101.71              7.67
# 33 2020-07-13 21:00:00    107.87              5.58
# 34 2020-07-14 00:00:00    104.58              7.16
# 35 2020-07-14 03:00:00     89.33              6.60
# 36 2020-07-14 06:00:00     86.14              9.08
# 37 2020-07-14 09:00:00     83.95             11.74
# 38 2020-07-14 12:00:00     81.97              9.24
# 39 2020-07-14 15:00:00     90.81              8.10

# %%
#Use the machine learning model developed previously to predict the Active Power and add the values to the existing Data Frame

import pickle
filename = 'WT_ActivePower_model.sav'
loaded_model = pickle.load(open(filename, 'rb'))

PredictedPowerArray=[]  

for index, row in dfWeatherForecast.iterrows():
    new_input = [[row['Temp (F)'], row['Wind Speed (m/s)']]]
    result = loaded_model.predict(new_input)
    np.array(PredictedPowerArray.append(result))
    
dfWeatherForecast['Predicted Active Power (kW)']=pd.DataFrame(PredictedPowerArray)

dfWeatherForecast
# Out:
#              Timestamp  Temp (F)  Wind Speed (m/s)  \
# 0  2020-07-09 18:00:00    102.42              5.91
# 1  2020-07-09 21:00:00    104.54              7.19
# 2  2020-07-10 00:00:00    102.43              4.40
# 3  2020-07-10 03:00:00     87.44              1.52
# 4  2020-07-10 06:00:00     84.72              7.96
# 5  2020-07-10 09:00:00     82.38              7.53
# 6  2020-07-10 12:00:00     78.12              4.63
# 7  2020-07-10 15:00:00     80.76              6.04
# 8  2020-07-10 18:00:00     91.27              3.72
# 9  2020-07-10 21:00:00     99.52              2.22
# 10 2020-07-11 00:00:00    101.21              2.21
# 11 2020-07-11 03:00:00     89.15              2.37
# 12 2020-07-11 06:00:00     86.61              4.72
# 13 2020-07-11 09:00:00     83.05              7.46
# 14 2020-07-11 12:00:00     80.40              5.94
# 15 2020-07-11 15:00:00     90.91              5.96
# 16 2020-07-11 18:00:00    101.71              3.84
# 17 2020-07-11 21:00:00    103.93              1.63
# 18 2020-07-12 00:00:00    101.95              1.00
# 19 2020-07-12 03:00:00     90.30              5.15
# 20 2020-07-12 06:00:00     81.25              4.52
# 21 2020-07-12 09:00:00     78.80              3.55
# 22 2020-07-12 12:00:00     75.20              4.47
# 23 2020-07-12 15:00:00     87.26              5.36
# 24 2020-07-12 18:00:00    102.78              8.63
# 25 2020-07-12 21:00:00    107.65              6.66
# 26 2020-07-13 00:00:00    100.94              1.93
# 27 2020-07-13 03:00:00     85.80              5.31
# 28 2020-07-13 06:00:00     81.30              2.14
# 29 2020-07-13 09:00:00     79.59              3.85
# 30 2020-07-13 12:00:00     79.45              6.01
# 31 2020-07-13 15:00:00     90.48              8.35
# 32 2020-07-13 18:00:00    101.71              7.67
# 33 2020-07-13 21:00:00    107.87              5.58
# 34 2020-07-14 00:00:00    104.58              7.16
# 35 2020-07-14 03:00:00     89.33              6.60
# 36 2020-07-14 06:00:00     86.14              9.08
# 37 2020-07-14 09:00:00     83.95             11.74
# 38 2020-07-14 12:00:00     81.97              9.24
# 39 2020-07-14 15:00:00     90.81              8.10
#
#     Predicted Active Power (kW)
# 0                    242.122865
# 1                    562.699881
# 2                     92.285506
# 3                     34.123415
# 4                    595.954338
# 5                    562.699881
# 6                    148.488162
# 7                    242.122865
# 8                     34.123415
# 9                     34.123415
# 10                    34.123415
# 11                    34.123415
# 12                   148.488162
# 13                   562.699881
# 14                   242.122865
# 15                   242.122865
# 16                    92.285506
# 17                    34.123415
# 18                    34.123415
# 19                   148.488162
# 20                    92.285506
# 21                    34.123415
# 22                    92.285506
# 23                   198.379212
# 24                   699.729297
# 25                   429.374661
# 26                    34.123415
# 27                   198.379212
# 28                    34.123415
# 29                    92.285506
# 30                   242.122865
# 31                   699.729297
# 32                   562.699881
# 33                   198.379212
# 34                   562.699881
# 35                   429.374661
# 36                   828.746138
# 37                  1490.622023
# 38                   871.084704
# 39                   595.954338

# %%
#Save data back to prediction stream in OCS

StreamId = "WT_5dForecast_01"
values = []

for index, row in dfWeatherForecast.iterrows():
        values.append({"Air_Temperature": row["Temp (F)"], "Wind_Speed": row["Wind Speed (m/s)"], 
                       "Predicted_Active_Power": row["Predicted Active Power (kW)"], "Timestamp": 
                       row["Timestamp"].strftime('%Y-%m-%d %H:%M:%S') })

ocsClient.Streams.updateValues(namespaceId, StreamId, json.dumps(values))
global finished
finished = True

# %%
import unittest
import xmlrunner

class TestNotebook(unittest.TestCase):
      
    def test_result(self):   
        global result
        
        self.assertIsNotNone(result)
        
    def test_finished(self):   
        global finished
        
        self.assertTrue(finished)

if __name__ == '__main__':    

    with open('test-SDSDataViewJupyter.xml', 'w') as output:
        unittest.main(argv=['first-arg-is-ignored'], testRunner=xmlrunner.XMLTestRunner(output=output), exit=False,
            failfast=False, buffer=False, catchbreak=False)
# Out:
# Running tests...
# ----------------------------------------------------------------------
# E.
# ======================================================================
# ERROR [0.002s]: test_finished (__main__.TestNotebook)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-29-0fcc0595ed4c>", line 14, in test_finished
#     self.assertTrue(finished)
# NameError: name 'finished' is not defined
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.003s
#
# FAILED (errors=1)
#
# Generating XML reports...
